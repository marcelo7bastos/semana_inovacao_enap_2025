# %% [markdown]
# # Análise Exploratório de Dados de financiamento com foco em sustentabilidade

# %% [markdown]
# ## SICOR - PRONAF

# %% [markdown]
# ## Preparando o ambiente de trabalho

# %%
import os
from google.colab import userdata

# 1) Montar o Drive
from google.colab import drive
drive.mount('/content/drive')

os.chdir("/content/drive/MyDrive/MDA/semana_inovacao_enap_2025")
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MDA/semana_inovacao_enap_2025

# %% [markdown]
# ## Análise Exploratória dos Dados

# %%
# Solução para carregar arquivos grander (maior que 100MB) dirto do google drive

# 1. Instale a biblioteca gdown (o '-q' é para uma instalação mais limpa)
#!pip install gdown -q

import pandas as pd
import gdown

# 2. Use o ID do seu arquivo para criar a URL de download
# Do seu link: https://drive.google.com/file/d/1nDdVu8vIB4HUIbFJ0Re2G_b6t6OcC9VQ/view?usp=sharing
#https://drive.google.com/file/d/1tDeXhOOJAQY_cKjzggOEhff0rGRmZTHs/view?usp=drive_link
# O ID é: 1nDdVu8vIB4HUIbFJ0Re2G_b6t6OcC9VQ
file_id = '1tDeXhOOJAQY_cKjzggOEhff0rGRmZTHs'
url_gdown = f'https://drive.google.com/uc?id={file_id}'



# 3. Defina um nome para o arquivo que será salvo no ambiente do Colab
output_filename = 'pronaf_local.parquet'

# 4. Faça o download com gdown (ele vai lidar com a página de aviso)
print(f"Baixando o arquivo '{output_filename}' do Google Drive... Isso pode levar um momento.")
gdown.download(url_gdown, output_filename, quiet=False)
print("Download concluído com sucesso!")

# 5. Agora, carregue o arquivo LOCAL que acabou de ser baixado
try:
    df_pronaf_semana_inovacao = pd.read_parquet(output_filename)
    print("\nArquivo Parquet carregado com sucesso para o DataFrame!")
    display(df_pronaf_semana_inovacao.head())
except Exception as e:
    print(f"\nOcorreu um erro ao ler o arquivo Parquet local: {e}")
# Out:
# Baixando o arquivo 'pronaf_local.parquet' do Google Drive... Isso pode levar um momento.
# Downloading...
# From (original): https://drive.google.com/uc?id=1tDeXhOOJAQY_cKjzggOEhff0rGRmZTHs
# From (redirected): https://drive.google.com/uc?id=1tDeXhOOJAQY_cKjzggOEhff0rGRmZTHs&confirm=t&uuid=c7343ecd-e33f-419e-8b07-fe65eec97842
# To: /content/drive/MyDrive/MDA/semana_inovacao_enap_2025/pronaf_local.parquet
# 100%|██████████| 142M/142M [00:01<00:00, 94.5MB/s]
# Download concluído com sucesso!
#
# Arquivo Parquet carregado com sucesso para o DataFrame!
#    REF_BACEN NU_ORDEM CD_ESTADO  CD_EMPREENDIMENTO  CD_PROGRAMA  \
# 1  515269303        1        RS     12017100000031            1
# 2  515269307        1        RS     22371300951408            1
# 3  515269309        1        PE     22371300190408            1
# 4  515269312        1        GO     22371300951408            1
# 5  515269313        1        GO     22371300190408            1
#
#    CD_TIPO_IRRIGACAO  CD_TIPO_AGRICULTURA CD_TIPO_CULTIVO  \
# 1                  1                    0              03
# 2                  0                    0              00
# 3                  0                    0              00
# 4                  0                    0              00
# 5                  0                    0              00
#
#    CD_TIPO_INTGR_CONSOR VL_PARC_CREDITO  ...  VL_TAXA_JUROS  \
# 1                     2        24845.33  ...           8.00
# 2                     0        53965.24  ...           8.00
# 3                     0        40026.60  ...           8.00
# 4                     0        49366.26  ...           8.00
# 5                     0        30314.93  ...           8.00
#
#    FLAG_VERDE_SUBPROGRAMA DESCRICAO_TIPO_IRRIGACAO FLAG_VERDE_TIPO_IRRIGACAO  \
# 1                     Não             Não Irrigado                       Sim
# 2                     Não            Não se aplica                       Não
# 3                     Não            Não se aplica                       Não
# 4                     Não            Não se aplica                       Não
# 5                     Não            Não se aplica                       Não
#
#                                   DESCRICAO_PROGRAMA FLAG_VERDE_PROGRAMA  \
# 1  PRONAF - PROGRAMA NACIONAL DE FORTALECIMENTO D...                 Sim
# 2  PRONAF - PROGRAMA NACIONAL DE FORTALECIMENTO D...                 Sim
# 3  PRONAF - PROGRAMA NACIONAL DE FORTALECIMENTO D...                 Sim
# 4  PRONAF - PROGRAMA NACIONAL DE FORTALECIMENTO D...                 Sim
# 5  PRONAF - PROGRAMA NACIONAL DE FORTALECIMENTO D...                 Sim
#
#    DESCRICAO_TIPO_INTGR_CONSOR FLAG_VERDE_TIPO_INTGR_CONSOR  \
# 1             Lavoura Solteira                          Não
# 2                Não se aplica                          Não
# 3                Não se aplica                          Não
# 4                Não se aplica                          Não
# 5                Não se aplica                          Não
#
#   DESCRICAO_TIPO_AGRICULTURA FLAG_VERDE_TIPO_AGRICULTURA
# 1              Não se aplica                         Não
# 2              Não se aplica                         Não
# 3              Não se aplica                         Não
# 4              Não se aplica                         Não
# 5              Não se aplica                         Não
#
# [5 rows x 42 columns]

# %%
# imprimir as informações gerais
df_pronaf_semana_inovacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4630235 entries, 1 to 5941287
# Data columns (total 42 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   REF_BACEN                     object
#  1   NU_ORDEM                      object
#  2   CD_ESTADO                     object
#  3   CD_EMPREENDIMENTO             int64
#  4   CD_PROGRAMA                   Int64
#  5   CD_TIPO_IRRIGACAO             Int64
#  6   CD_TIPO_AGRICULTURA           Int64
#  7   CD_TIPO_CULTIVO               object
#  8   CD_TIPO_INTGR_CONSOR          Int64
#  9   VL_PARC_CREDITO               object
#  10  CD_SUBPROGRAMA                Int64
#  11  ANO                           int32
#  12  SAFRA                         object
#  13  CD_IBGE_MUNICIPIO             object
#  14  CD_CPF_CNPJ                   object
#  15  SEXO_BIOLOGICO                object
#  16  CD_TIPO_BENEFICIARIO          Int64
#  17  FINALIDADE                    object
#  18  MODALIDADE                    object
#  19  PRODUTO                       object
#  20  CESTA_SAFRA                   object
#  21  CONSORCIO                     object
#  22  CD_TIPO_CULTURA               Int64
#  23  DESCRICAO_TIPO_CULTURA        object
#  24  FLAG_VERDE_TIPO_CULTURA       object
#  25  FLAG_VERDE_CONSORCIO          object
#  26  FLAG_VERDE_CESTA_SAFRA        object
#  27  FLAG_VERDE_PRODUTO            object
#  28  FLAG_VERDE_MODALIDADE         object
#  29  DESCRICAO_TIPO_BENEFICIARIO   object
#  30  FLAG_VERDE_TIPO_BENEFICIARIO  object
#  31  DESCRICAO_SUBPROGRAMA         object
#  32  VL_TAXA_JUROS                 float64
#  33  FLAG_VERDE_SUBPROGRAMA        object
#  34  DESCRICAO_TIPO_IRRIGACAO      object
#  35  FLAG_VERDE_TIPO_IRRIGACAO     object
#  36  DESCRICAO_PROGRAMA            object
#  37  FLAG_VERDE_PROGRAMA           object
#  38  DESCRICAO_TIPO_INTGR_CONSOR   object
#  39  FLAG_VERDE_TIPO_INTGR_CONSOR  object
#  40  DESCRICAO_TIPO_AGRICULTURA    object
#  41  FLAG_VERDE_TIPO_AGRICULTURA   object
# dtypes: Int64(7), float64(1), int32(1), int64(1), object(32)
# memory usage: 1.5+ GB

# %%
# Limpeza e declaração de tipo adequada
# Boa prática: fazer uma cópia do dataframe original antes da limpeza dos dados

# seleção de variáveis - remover lista:
colunas_de_interesse = [
    "REF_BACEN",#
    "NU_ORDEM",#
    "CD_ESTADO",
    "CD_EMPREENDIMENTO",#
    "CD_PROGRAMA",#
    "CD_TIPO_IRRIGACAO",#
    "CD_TIPO_AGRICULTURA",#
    "CD_TIPO_CULTIVO",
    "CD_TIPO_INTGR_CONSOR",#
    "VL_PARC_CREDITO",
    "CD_SUBPROGRAMA",#
    "ANO",
    "SAFRA",
    "CD_IBGE_MUNICIPIO",
    "CD_CPF_CNPJ",
    "SEXO_BIOLOGICO",
    "CD_TIPO_BENEFICIARIO",#
    "FINALIDADE",
    "MODALIDADE",
    "PRODUTO",
    "CESTA_SAFRA",
    "CONSORCIO",
    "CD_TIPO_CULTURA",#
    "DESCRICAO_TIPO_CULTURA",
    "FLAG_VERDE_TIPO_CULTURA",
    "FLAG_VERDE_CONSORCIO",
    "FLAG_VERDE_CESTA_SAFRA",
    "FLAG_VERDE_PRODUTO",
    "FLAG_VERDE_MODALIDADE",
    "DESCRICAO_TIPO_BENEFICIARIO",
    "FLAG_VERDE_TIPO_BENEFICIARIO",
    "DESCRICAO_SUBPROGRAMA",
    "VL_TAXA_JUROS",
    "FLAG_VERDE_SUBPROGRAMA",
    "DESCRICAO_TIPO_IRRIGACAO",
    "FLAG_VERDE_TIPO_IRRIGACAO",
    "DESCRICAO_PROGRAMA",
    "FLAG_VERDE_PROGRAMA",
    "DESCRICAO_TIPO_INTGR_CONSOR",
    "FLAG_VERDE_TIPO_INTGR_CONSOR",
    "DESCRICAO_TIPO_AGRICULTURA",
    "FLAG_VERDE_TIPO_AGRICULTURA",
]


# seleciona apenas as colunas de interesse a partir do DataFrame base
df_pronaf_semana_inovacao = df_pronaf_semana_inovacao[colunas_de_interesse]

# em df_pronaf_semana_inovacao_limpo variável VL_PARC_CREDITO para o tipo float64
df_pronaf_semana_inovacao['VL_PARC_CREDITO'] = df_pronaf_semana_inovacao['VL_PARC_CREDITO'].astype('float64')

df_pronaf_semana_inovacao['FLAG_VERDE_TIPO_BENEFICIARIO'] = (
    df_pronaf_semana_inovacao['FLAG_VERDE_TIPO_BENEFICIARIO'].fillna('Não')
)

df_pronaf_semana_inovacao['FLAG_VERDE_TIPO_CULTURA'] = (
    df_pronaf_semana_inovacao['FLAG_VERDE_TIPO_CULTURA'].fillna('Não')
)

# imprimir as informações gerais
df_pronaf_semana_inovacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4630235 entries, 1 to 5941287
# Data columns (total 42 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   REF_BACEN                     object
#  1   NU_ORDEM                      object
#  2   CD_ESTADO                     object
#  3   CD_EMPREENDIMENTO             int64
#  4   CD_PROGRAMA                   Int64
#  5   CD_TIPO_IRRIGACAO             Int64
#  6   CD_TIPO_AGRICULTURA           Int64
#  7   CD_TIPO_CULTIVO               object
#  8   CD_TIPO_INTGR_CONSOR          Int64
#  9   VL_PARC_CREDITO               float64
#  10  CD_SUBPROGRAMA                Int64
#  11  ANO                           int32
#  12  SAFRA                         object
#  13  CD_IBGE_MUNICIPIO             object
#  14  CD_CPF_CNPJ                   object
#  15  SEXO_BIOLOGICO                object
#  16  CD_TIPO_BENEFICIARIO          Int64
#  17  FINALIDADE                    object
#  18  MODALIDADE                    object
#  19  PRODUTO                       object
#  20  CESTA_SAFRA                   object
#  21  CONSORCIO                     object
#  22  CD_TIPO_CULTURA               Int64
#  23  DESCRICAO_TIPO_CULTURA        object
#  24  FLAG_VERDE_TIPO_CULTURA       object
#  25  FLAG_VERDE_CONSORCIO          object
#  26  FLAG_VERDE_CESTA_SAFRA        object
#  27  FLAG_VERDE_PRODUTO            object
#  28  FLAG_VERDE_MODALIDADE         object
#  29  DESCRICAO_TIPO_BENEFICIARIO   object
#  30  FLAG_VERDE_TIPO_BENEFICIARIO  object
#  31  DESCRICAO_SUBPROGRAMA         object
#  32  VL_TAXA_JUROS                 float64
#  33  FLAG_VERDE_SUBPROGRAMA        object
#  34  DESCRICAO_TIPO_IRRIGACAO      object
#  35  FLAG_VERDE_TIPO_IRRIGACAO     object
#  36  DESCRICAO_PROGRAMA            object
#  37  FLAG_VERDE_PROGRAMA           object
#  38  DESCRICAO_TIPO_INTGR_CONSOR   object
#  39  FLAG_VERDE_TIPO_INTGR_CONSOR  object
#  40  DESCRICAO_TIPO_AGRICULTURA    object
#  41  FLAG_VERDE_TIPO_AGRICULTURA   object
# dtypes: Int64(7), float64(2), int32(1), int64(1), object(31)
# memory usage: 1.5+ GB

# %%
# imprimir as principais estatísticas descritivas do dataframe df com decribe
df_pronaf_semana_inovacao.describe(include='all')
# Out:
#         REF_BACEN NU_ORDEM CD_ESTADO     CD_EMPREENDIMENTO  CD_PROGRAMA  \
# count     4630235  4630235   4630235          4,630,235.00 4,630,235.00
# unique    3570721       22        27                   NaN         <NA>
# top     515945061        1        BA                   NaN         <NA>
# freq           72  3576020    682065                   NaN         <NA>
# mean          NaN      NaN       NaN 19,098,472,198,225.80         2.27
# std           NaN      NaN       NaN  5,111,197,649,760.17        15.23
# min           NaN      NaN       NaN 12,010,020,000,042.00         1.00
# 25%           NaN      NaN       NaN 13,143,330,352,042.00         1.00
# 50%           NaN      NaN       NaN 22,371,300,190,408.00         1.00
# 75%           NaN      NaN       NaN 23,271,300,193,002.00         1.00
# max           NaN      NaN       NaN 24,400,841,000,408.00       222.00
#
#         CD_TIPO_IRRIGACAO  CD_TIPO_AGRICULTURA CD_TIPO_CULTIVO  \
# count        4,630,235.00         4,630,235.00         4630235
# unique               <NA>                 <NA>              19
# top                  <NA>                 <NA>              00
# freq                 <NA>                 <NA>         4527872
# mean                 0.22                 0.82             NaN
# std                  0.71                 1.93             NaN
# min                  0.00                 0.00             NaN
# 25%                  0.00                 0.00             NaN
# 50%                  0.00                 0.00             NaN
# 75%                  0.00                 0.00             NaN
# max                 11.00                 9.00             NaN
#
#         CD_TIPO_INTGR_CONSOR  VL_PARC_CREDITO  ...  VL_TAXA_JUROS  \
# count           4,630,235.00     4,630,235.00  ...   4,630,235.00
# unique                  <NA>              NaN  ...            NaN
# top                     <NA>              NaN  ...            NaN
# freq                    <NA>              NaN  ...            NaN
# mean                    0.34        39,963.94  ...           3.86
# std                     0.75       178,111.64  ...           3.71
# min                     0.00             0.01  ...           0.50
# 25%                     0.00         6,000.00  ...           0.50
# 50%                     0.00        12,000.00  ...           0.50
# 75%                     0.00        42,773.74  ...           8.00
# max                     7.00    50,000,000.00  ...          10.50
#
#         FLAG_VERDE_SUBPROGRAMA DESCRICAO_TIPO_IRRIGACAO  \
# count                  4630235                  4630235
# unique                       2                       12
# top                        Não            Não se aplica
# freq                   4522958                  3851360
# mean                       NaN                      NaN
# std                        NaN                      NaN
# min                        NaN                      NaN
# 25%                        NaN                      NaN
# 50%                        NaN                      NaN
# 75%                        NaN                      NaN
# max                        NaN                      NaN
#
#        FLAG_VERDE_TIPO_IRRIGACAO  \
# count                    4630235
# unique                         2
# top                          Não
# freq                     3889678
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
#                                        DESCRICAO_PROGRAMA FLAG_VERDE_PROGRAMA  \
# count                                             4630235             4630235
# unique                                                  5                   1
# top     PRONAF - PROGRAMA NACIONAL DE FORTALECIMENTO D...                 Sim
# freq                                              4597102             4630235
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#         DESCRICAO_TIPO_INTGR_CONSOR FLAG_VERDE_TIPO_INTGR_CONSOR  \
# count                       4630235                      4630235
# unique                            8                            2
# top                   Não se aplica                          Não
# freq                        3854075                      4621829
# mean                            NaN                          NaN
# std                             NaN                          NaN
# min                             NaN                          NaN
# 25%                             NaN                          NaN
# 50%                             NaN                          NaN
# 75%                             NaN                          NaN
# max                             NaN                          NaN
#
#        DESCRICAO_TIPO_AGRICULTURA FLAG_VERDE_TIPO_AGRICULTURA
# count                     4630235                     4630235
# unique                          8                           2
# top                 Não se aplica                         Não
# freq                      3832980                     4427514
# mean                          NaN                         NaN
# std                           NaN                         NaN
# min                           NaN                         NaN
# 25%                           NaN                         NaN
# 50%                           NaN                         NaN
# 75%                           NaN                         NaN
# max                           NaN                         NaN
#
# [11 rows x 42 columns]

# %% [markdown]
# # Análise exploratória

# %%
# bibliotecas
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Variáveis de controle
#
#
#
# ```
# REF_BACEN
# NU_ORDEM
# CD_EMPREENDIMENTO
# ```

# %% [markdown]
# ## Estado

# %%
df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index='CD_ESTADO',
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# ordena pelo ano de 2023 (coluna da pivot_table)
df_pivotado = df_pivotado.sort_values(by=2023, ascending=False)

display(df_pivotado)
# Out:
# ANO                    2023              2024              2025
# CD_ESTADO
# RS        16,167,553,746.26 17,816,968,762.90 11,331,376,488.56
# PR         9,390,425,990.35  9,628,585,623.22  5,993,399,992.35
# SC         8,178,231,356.97  9,035,695,787.37  6,496,767,769.20
# MG         7,199,711,278.23  8,080,561,909.91  4,382,326,760.62
# MT         3,298,786,163.22  3,053,478,754.74  1,396,052,804.89
# BA         3,012,091,802.06  3,988,330,190.93  2,622,261,304.01
# RO         2,415,991,981.18  2,541,517,317.63  1,353,878,761.65
# ES         1,993,192,224.36  2,552,173,137.53  1,537,370,798.44
# GO         1,854,643,400.43  1,919,981,924.04    940,805,016.38
# SP         1,461,747,181.11  1,700,646,521.87    934,194,581.79
# PA         1,412,278,825.39  1,986,158,034.02  1,236,788,033.87
# MA         1,309,000,947.44  1,921,420,250.91  1,023,239,640.06
# PE         1,148,521,799.08  1,695,998,669.26  1,038,968,764.57
# CE         1,098,778,900.39  1,569,014,774.69  1,067,089,725.72
# PI           882,217,693.98  1,254,218,872.12    711,415,587.89
# MS           653,613,861.21    679,489,599.73    442,857,173.40
# PB           650,519,409.98    896,620,364.50    547,447,826.42
# SE           599,941,947.78    831,711,066.67    722,637,229.70
# AL           558,546,367.45    737,824,512.11    456,061,067.29
# TO           497,438,228.14    660,980,365.52    415,216,112.34
# AC           416,054,484.97    518,743,362.52    295,829,605.01
# RN           394,255,433.01    562,349,534.84    371,725,427.37
# RJ           283,544,708.97    322,719,286.41    178,868,801.64
# RR           155,450,742.69    173,265,118.28    123,272,070.02
# AM            70,115,055.69     72,777,402.02     55,711,620.90
# AP            15,435,928.10     16,216,049.27     22,744,825.55
# DF             2,899,531.77      3,528,038.62      2,144,887.97

# %% [markdown]
# ## Município

# %%
df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['CD_IBGE_MUNICIPIO', 'CD_ESTADO'],  # primeiro município, depois estado
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# ordena por 2023
df_pivotado = df_pivotado.sort_values(by=2023, ascending=False)

display(df_pivotado)
# Out:
# ANO                                   2023           2024           2025
# CD_IBGE_MUNICIPIO CD_ESTADO
# 1100205           RO        247,216,624.34 202,058,210.59 116,829,397.54
# 4208500           SC        187,918,461.19 215,382,060.20 174,625,571.54
# 4107207           PR        174,126,307.39 153,596,912.35  78,179,981.89
# 4200705           SC        172,381,522.92 195,721,931.85 160,672,072.05
# 4128609           PR        163,137,307.95 163,391,426.47 173,107,147.55
# ...                                    ...            ...            ...
# 3300951           RJ                  0.00     140,000.00           0.00
# 1302207           AM                  0.00           0.00       4,000.00
# 1300607           AM                  0.00      30,000.00           0.00
# 1300805           AM                  0.00   1,311,260.21     797,143.02
# 1300839           AM                  0.00           0.00      79,512.00
#
# [5449 rows x 3 columns]

# %% [markdown]
# ## SEXO

# %%
df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['SEXO_BIOLOGICO'],  # primeiro município, depois estado
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# ordena por 2023
df_pivotado = df_pivotado.sort_values(by=2023, ascending=False)

display(df_pivotado)
# Out:
# ANO                         2023              2024              2025
# SEXO_BIOLOGICO
# Masculino      42,410,616,069.67 46,799,265,173.62 25,219,839,762.79
# Feminino       11,948,036,965.84 14,447,277,011.40  9,269,481,132.58

# %% [markdown]
# ## Descrição do Beneficiário

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_BENEFICIARIO', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_BENEFICIARIO', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)


df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_TIPO_BENEFICIARIO', 'CD_TIPO_BENEFICIARIO', 'DESCRICAO_TIPO_BENEFICIARIO'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                               % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_TIPO_BENEFICIARIO
# Não                                           99.62                    98.12
# Sim                                            0.38                     1.88
# <style type="text/css">
# #T_aab25 th.row_heading {
#   text-align: left;
# }
# #T_aab25 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_aab25" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_aab25_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_aab25_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_aab25_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_TIPO_BENEFICIARIO</th>
#       <th class="index_name level1" >CD_TIPO_BENEFICIARIO</th>
#       <th class="index_name level2" >DESCRICAO_TIPO_BENEFICIARIO</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aab25_level0_row0" class="row_heading level0 row0" rowspan="8">Não</th>
#       <th id="T_aab25_level1_row0" class="row_heading level1 row0" >1</th>
#       <th id="T_aab25_level2_row0" class="row_heading level2 row0" >Produtor rural (pessoa física ou jurídica) - (MCR 1-4-1-a)</th>
#       <td id="T_aab25_row0_col0" class="data row0 col0" >54.772.065.814,59</td>
#       <td id="T_aab25_row0_col1" class="data row0 col1" >61.647.815.696,68</td>
#       <td id="T_aab25_row0_col2" class="data row0 col2" >34.270.725.785,21</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row1" class="row_heading level1 row1" >2</th>
#       <th id="T_aab25_level2_row1" class="row_heading level2 row1" >Cooperativa de produção agropecuária – na condição de sociedade prestadora de serviços de natureza agropecuária aos seus cooperados (MCR 5-1-2-b e c)</th>
#       <td id="T_aab25_row1_col0" class="data row1 col0" >256.102.444,09</td>
#       <td id="T_aab25_row1_col1" class="data row1 col1" >449.027.389,65</td>
#       <td id="T_aab25_row1_col2" class="data row1 col2" >223.107.462,12</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row2" class="row_heading level1 row2" >3</th>
#       <th id="T_aab25_level2_row2" class="row_heading level2 row2" >Cooperativa de produção agropecuária – na condição de produtor rural - (MCR 5-1-2-a)</th>
#       <td id="T_aab25_row2_col0" class="data row2 col0" >156.110.348,97</td>
#       <td id="T_aab25_row2_col1" class="data row2 col1" >6.105.601,00</td>
#       <td id="T_aab25_row2_col2" class="data row2 col2" >611.023,10</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row3" class="row_heading level1 row3" >5</th>
#       <th id="T_aab25_level2_row3" class="row_heading level2 row3" >Pessoa física ou jurídica da atividade de pesquisa agropecuária (MCR 1-4-2-a e b)</th>
#       <td id="T_aab25_row3_col0" class="data row3 col0" >4.638.055,36</td>
#       <td id="T_aab25_row3_col1" class="data row3 col1" >613.775,45</td>
#       <td id="T_aab25_row3_col2" class="data row3 col2" >237.467,04</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row4" class="row_heading level1 row4" >8</th>
#       <th id="T_aab25_level2_row4" class="row_heading level2 row4" >Beneficiador (MCR 1-4-2A-a)</th>
#       <td id="T_aab25_row4_col0" class="data row4 col0" >0,00</td>
#       <td id="T_aab25_row4_col1" class="data row4 col1" >1.469.619,96</td>
#       <td id="T_aab25_row4_col2" class="data row4 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row5" class="row_heading level1 row5" >9</th>
#       <th id="T_aab25_level2_row5" class="row_heading level2 row5" >Agroindústria (MCR 1-4-2A-a)</th>
#       <td id="T_aab25_row5_col0" class="data row5 col0" >0,00</td>
#       <td id="T_aab25_row5_col1" class="data row5 col1" >17.668.151,51</td>
#       <td id="T_aab25_row5_col2" class="data row5 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row6" class="row_heading level1 row6" >13</th>
#       <th id="T_aab25_level2_row6" class="row_heading level2 row6" >Aquicultor (MCR 2-1-20)</th>
#       <td id="T_aab25_row6_col0" class="data row6 col0" >27.569.042,16</td>
#       <td id="T_aab25_row6_col1" class="data row6 col1" >22.526.071,78</td>
#       <td id="T_aab25_row6_col2" class="data row6 col2" >25.546.491,79</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row7" class="row_heading level1 row7" >16</th>
#       <th id="T_aab25_level2_row7" class="row_heading level2 row7" >Silvicultor (MCR 10-2-2-a-III)</th>
#       <td id="T_aab25_row7_col0" class="data row7 col0" >16.186.375,98</td>
#       <td id="T_aab25_row7_col1" class="data row7 col1" >43.914.906,71</td>
#       <td id="T_aab25_row7_col2" class="data row7 col2" >72.501.314,38</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level0_row8" class="row_heading level0 row8" rowspan="5">Sim</th>
#       <th id="T_aab25_level1_row8" class="row_heading level1 row8" >6</th>
#       <th id="T_aab25_level2_row8" class="row_heading level2 row8" >Pessoa física ou jurídica produtora de mudas, sementes, sêmen para inseminação artificial e embriões (MCR 1-4-2-a e b)</th>
#       <td id="T_aab25_row8_col0" class="data row8 col0" >705.331,60</td>
#       <td id="T_aab25_row8_col1" class="data row8 col1" >39.288,82</td>
#       <td id="T_aab25_row8_col2" class="data row8 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row9" class="row_heading level1 row9" >11</th>
#       <th id="T_aab25_level2_row9" class="row_heading level2 row9" >Silvícola/indígena (MCR 1-4-3)</th>
#       <td id="T_aab25_row9_col0" class="data row9 col0" >28.379.506,63</td>
#       <td id="T_aab25_row9_col1" class="data row9 col1" >56.567.889,22</td>
#       <td id="T_aab25_row9_col2" class="data row9 col2" >67.558.139,62</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row10" class="row_heading level1 row10" >12</th>
#       <th id="T_aab25_level2_row10" class="row_heading level2 row10" >Pescador (MCR 2-1-15 e 20)</th>
#       <td id="T_aab25_row10_col0" class="data row10 col0" >28.120.667,58</td>
#       <td id="T_aab25_row10_col1" class="data row10 col1" >115.832.171,28</td>
#       <td id="T_aab25_row10_col2" class="data row10 col2" >140.441.570,69</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row11" class="row_heading level1 row11" >17</th>
#       <th id="T_aab25_level2_row11" class="row_heading level2 row11" >Extrativista (MCR 2-1-15)</th>
#       <td id="T_aab25_row11_col0" class="data row11 col0" >48.309.054,94</td>
#       <td id="T_aab25_row11_col1" class="data row11 col1" >93.772.380,58</td>
#       <td id="T_aab25_row11_col2" class="data row11 col2" >92.022.587,89</td>
#     </tr>
#     <tr>
#       <th id="T_aab25_level1_row12" class="row_heading level1 row12" >18</th>
#       <th id="T_aab25_level2_row12" class="row_heading level2 row12" >Quilombola rural (MCR 10-2-2-b-II)</th>
#       <td id="T_aab25_row12_col0" class="data row12 col0" >3.203.897,48</td>
#       <td id="T_aab25_row12_col1" class="data row12 col1" >9.707.282,47</td>
#       <td id="T_aab25_row12_col2" class="data row12 col2" >11.829.909,86</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Política Pública

# %% [markdown]
# ### Programa

# %%
df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_PROGRAMA', 'CD_PROGRAMA', 'DESCRICAO_PROGRAMA'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
# <style type="text/css">
# #T_96831 th.row_heading {
#   text-align: left;
# }
# #T_96831 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_96831" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_96831_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_96831_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_96831_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_PROGRAMA</th>
#       <th class="index_name level1" >CD_PROGRAMA</th>
#       <th class="index_name level2" >DESCRICAO_PROGRAMA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96831_level0_row0" class="row_heading level0 row0" rowspan="5">Sim</th>
#       <th id="T_96831_level1_row0" class="row_heading level1 row0" >1</th>
#       <th id="T_96831_level2_row0" class="row_heading level2 row0" >PRONAF - PROGRAMA NACIONAL DE FORTALECIMENTO DA AGRICULTURA FAMILIAR</th>
#       <td id="T_96831_row0_col0" class="data row0 col0" >56.390.487.582,00</td>
#       <td id="T_96831_row0_col1" class="data row0 col1" >65.898.660.589,48</td>
#       <td id="T_96831_row0_col2" class="data row0 col2" >41.625.143.608,11</td>
#     </tr>
#     <tr>
#       <th id="T_96831_level1_row1" class="row_heading level1 row1" >153</th>
#       <th id="T_96831_level2_row1" class="row_heading level2 row1" >MODERAGRO - PROGRAMA DE MODERNIZAÇÃO DA AGRICULTURA E CONSERVAÇÃO DE RECURSOS NATURAIS</th>
#       <td id="T_96831_row1_col0" class="data row1 col0" >3.027.378.134,16</td>
#       <td id="T_96831_row1_col1" class="data row1 col1" >2.696.915.229,87</td>
#       <td id="T_96831_row1_col2" class="data row1 col2" >814.405.833,82</td>
#     </tr>
#     <tr>
#       <th id="T_96831_level1_row2" class="row_heading level1 row2" >156</th>
#       <th id="T_96831_level2_row2" class="row_heading level2 row2" >ABC + Programa para a Adaptação à Mudança do Clima e Baixa Emissão de Carbono""</th>
#       <td id="T_96831_row2_col0" class="data row2 col0" >718.823.441,22</td>
#       <td id="T_96831_row2_col1" class="data row2 col1" >0,00</td>
#       <td id="T_96831_row2_col2" class="data row2 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_96831_level1_row3" class="row_heading level1 row3" >201</th>
#       <th id="T_96831_level2_row3" class="row_heading level2 row3" >PROGRAMA NACIONAL DE CRÉDITO FUNDIÁRIO (FTRA)</th>
#       <td id="T_96831_row3_col0" class="data row3 col0" >236.967.912,61</td>
#       <td id="T_96831_row3_col1" class="data row3 col1" >285.712.743,41</td>
#       <td id="T_96831_row3_col2" class="data row3 col2" >201.600.965,13</td>
#     </tr>
#     <tr>
#       <th id="T_96831_level1_row4" class="row_heading level1 row4" >222</th>
#       <th id="T_96831_level2_row4" class="row_heading level2 row4" >RenovAgro - Programa de Financiamento a Sistemas de Produção Agropecuária Sustentáveis</th>
#       <td id="T_96831_row4_col0" class="data row4 col0" >4.747.331.920,22</td>
#       <td id="T_96831_row4_col1" class="data row4 col1" >5.339.686.668,87</td>
#       <td id="T_96831_row4_col2" class="data row4 col2" >3.059.302.270,55</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Subprograma

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_SUBPROGRAMA', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_SUBPROGRAMA', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_SUBPROGRAMA', 'CD_SUBPROGRAMA', 'DESCRICAO_SUBPROGRAMA'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                         % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_SUBPROGRAMA
# Não                                     97.18                    96.56
# Sim                                      2.82                     3.44
# <style type="text/css">
# #T_8c9f3 th.row_heading {
#   text-align: left;
# }
# #T_8c9f3 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_8c9f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_8c9f3_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_8c9f3_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_8c9f3_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_SUBPROGRAMA</th>
#       <th class="index_name level1" >CD_SUBPROGRAMA</th>
#       <th class="index_name level2" >DESCRICAO_SUBPROGRAMA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c9f3_level0_row0" class="row_heading level0 row0" rowspan="33">Não</th>
#       <th id="T_8c9f3_level1_row0" class="row_heading level1 row0" >1</th>
#       <th id="T_8c9f3_level2_row0" class="row_heading level2 row0" >Custeio (MCR 10-4)</th>
#       <td id="T_8c9f3_row0_col0" class="data row0 col0" >31.625.684.272,88</td>
#       <td id="T_8c9f3_row0_col1" class="data row0 col1" >31.356.413.262,72</td>
#       <td id="T_8c9f3_row0_col2" class="data row0 col2" >21.878.926.848,80</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row1" class="row_heading level1 row1" >2</th>
#       <th id="T_8c9f3_level2_row1" class="row_heading level2 row1" >Mais Alimentos (MCR 10-5)</th>
#       <td id="T_8c9f3_row1_col0" class="data row1 col0" >15.482.202.758,19</td>
#       <td id="T_8c9f3_row1_col1" class="data row1 col1" >21.951.254.427,20</td>
#       <td id="T_8c9f3_row1_col2" class="data row1 col2" >10.596.099.292,96</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row2" class="row_heading level1 row2" >3</th>
#       <th id="T_8c9f3_level2_row2" class="row_heading level2 row2" >Agroindústria (investimento) (MCR 10-6)</th>
#       <td id="T_8c9f3_row2_col0" class="data row2 col0" >558.785.186,65</td>
#       <td id="T_8c9f3_row2_col1" class="data row2 col1" >782.391.163,71</td>
#       <td id="T_8c9f3_row2_col2" class="data row2 col2" >191.386.154,18</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row3" class="row_heading level1 row3" >6</th>
#       <th id="T_8c9f3_level2_row3" class="row_heading level2 row3" >Jovem (MCR 10-10)</th>
#       <td id="T_8c9f3_row3_col0" class="data row3 col0" >868.319,11</td>
#       <td id="T_8c9f3_row3_col1" class="data row3 col1" >854.836,52</td>
#       <td id="T_8c9f3_row3_col2" class="data row3 col2" >1.774.703,81</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row4" class="row_heading level1 row4" >7</th>
#       <th id="T_8c9f3_level2_row4" class="row_heading level2 row4" >Cotas Partes (MCR 10-12)</th>
#       <td id="T_8c9f3_row4_col0" class="data row4 col0" >476.281.000,00</td>
#       <td id="T_8c9f3_row4_col1" class="data row4 col1" >447.729.000,00</td>
#       <td id="T_8c9f3_row4_col2" class="data row4 col2" >214.350.000,00</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row5" class="row_heading level1 row5" >27</th>
#       <th id="T_8c9f3_level2_row5" class="row_heading level2 row5" >Recuperação de Solos (MCR 11-4-1-"a"-V)</th>
#       <td id="T_8c9f3_row5_col0" class="data row5 col0" >33.608.859,67</td>
#       <td id="T_8c9f3_row5_col1" class="data row5 col1" >120.814.123,28</td>
#       <td id="T_8c9f3_row5_col2" class="data row5 col2" >7.999.546,78</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row6" class="row_heading level1 row6" >28</th>
#       <th id="T_8c9f3_level2_row6" class="row_heading level2 row6" >Fomentação Prod Benef Industr Acond Armaz (MCR 11-4-"a"-I)</th>
#       <td id="T_8c9f3_row6_col0" class="data row6 col0" >2.689.183.643,02</td>
#       <td id="T_8c9f3_row6_col1" class="data row6 col1" >1.964.455.017,31</td>
#       <td id="T_8c9f3_row6_col2" class="data row6 col2" >625.185.690,87</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row7" class="row_heading level1 row7" >29</th>
#       <th id="T_8c9f3_level2_row7" class="row_heading level2 row7" >Fomentação de Ações de Defesa Animal (MCR 11-4-"a"-II)</th>
#       <td id="T_8c9f3_row7_col0" class="data row7 col0" >233.876.862,61</td>
#       <td id="T_8c9f3_row7_col1" class="data row7 col1" >550.191.446,53</td>
#       <td id="T_8c9f3_row7_col2" class="data row7 col2" >151.486.819,72</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row8" class="row_heading level1 row8" >32</th>
#       <th id="T_8c9f3_level2_row8" class="row_heading level2 row8" >ABC + Recuperação - (MCR 11-7-1-"c"-I)</th>
#       <td id="T_8c9f3_row8_col0" class="data row8 col0" >125.782.485,36</td>
#       <td id="T_8c9f3_row8_col1" class="data row8 col1" >0,00</td>
#       <td id="T_8c9f3_row8_col2" class="data row8 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row9" class="row_heading level1 row9" >34</th>
#       <th id="T_8c9f3_level2_row9" class="row_heading level2 row9" >ABC + Plantio Direto (MCR 11-7-1-"c"-III)</th>
#       <td id="T_8c9f3_row9_col0" class="data row9 col0" >170.272.184,90</td>
#       <td id="T_8c9f3_row9_col1" class="data row9 col1" >0,00</td>
#       <td id="T_8c9f3_row9_col2" class="data row9 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row10" class="row_heading level1 row10" >35</th>
#       <th id="T_8c9f3_level2_row10" class="row_heading level2 row10" >ABC + Integração - (MCR 11-7-1-"c"-IV)</th>
#       <td id="T_8c9f3_row10_col0" class="data row10 col0" >77.650.277,34</td>
#       <td id="T_8c9f3_row10_col1" class="data row10 col1" >0,00</td>
#       <td id="T_8c9f3_row10_col2" class="data row10 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row11" class="row_heading level1 row11" >36</th>
#       <th id="T_8c9f3_level2_row11" class="row_heading level2 row11" >ABC + Florestas - (MCR 11-7-1-"c"-V)</th>
#       <td id="T_8c9f3_row11_col0" class="data row11 col0" >95.514.130,36</td>
#       <td id="T_8c9f3_row11_col1" class="data row11 col1" >0,00</td>
#       <td id="T_8c9f3_row11_col2" class="data row11 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row12" class="row_heading level1 row12" >37</th>
#       <th id="T_8c9f3_level2_row12" class="row_heading level2 row12" >ABC + Ambiental - (MCR 11-7-1-"c"-VI)</th>
#       <td id="T_8c9f3_row12_col0" class="data row12 col0" >8.663.938,31</td>
#       <td id="T_8c9f3_row12_col1" class="data row12 col1" >0,00</td>
#       <td id="T_8c9f3_row12_col2" class="data row12 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row13" class="row_heading level1 row13" >38</th>
#       <th id="T_8c9f3_level2_row13" class="row_heading level2 row13" >ABC + Manejo de Resíduos - (MCR 11-7-1-"c"-VII)</th>
#       <td id="T_8c9f3_row13_col0" class="data row13 col0" >2.648.999,99</td>
#       <td id="T_8c9f3_row13_col1" class="data row13 col1" >0,00</td>
#       <td id="T_8c9f3_row13_col2" class="data row13 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row14" class="row_heading level1 row14" >53</th>
#       <th id="T_8c9f3_level2_row14" class="row_heading level2 row14" >Pronaf Industrialização Agroind. Familiar (MCR10-11)</th>
#       <td id="T_8c9f3_row14_col0" class="data row14 col0" >1.924.202.340,73</td>
#       <td id="T_8c9f3_row14_col1" class="data row14 col1" >1.467.940.648,48</td>
#       <td id="T_8c9f3_row14_col2" class="data row14 col2" >1.275.154.813,19</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row15" class="row_heading level1 row15" >54</th>
#       <th id="T_8c9f3_level2_row15" class="row_heading level2 row15" >Reforma Agrária Beneficiários PNCF, PNRA, PCRF (MCR10-3)</th>
#       <td id="T_8c9f3_row15_col0" class="data row15 col0" >179.060.272,41</td>
#       <td id="T_8c9f3_row15_col1" class="data row15 col1" >348.855.632,25</td>
#       <td id="T_8c9f3_row15_col2" class="data row15 col2" >587.589.541,13</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f3_level1_row16

# %% [markdown]
# ## Caracterização da Operação

# %% [markdown]
# ### Finalidade

# %%
df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FINALIDADE'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
# <style type="text/css">
# #T_eafc4 th.row_heading {
#   text-align: left;
# }
# #T_eafc4 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_eafc4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_eafc4_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_eafc4_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_eafc4_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FINALIDADE</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eafc4_level0_row0" class="row_heading level0 row0" >Custeio</th>
#       <td id="T_eafc4_row0_col0" class="data row0 col0" >32.334.717.050,38</td>
#       <td id="T_eafc4_row0_col1" class="data row0 col1" >32.699.384.187,64</td>
#       <td id="T_eafc4_row0_col2" class="data row0 col2" >22.391.647.121,02</td>
#     </tr>
#     <tr>
#       <th id="T_eafc4_level0_row1" class="row_heading level0 row1" >Industrialização</th>
#       <td id="T_eafc4_row1_col0" class="data row1 col0" >1.895.697.057,85</td>
#       <td id="T_eafc4_row1_col1" class="data row1 col1" >1.450.280.381,53</td>
#       <td id="T_eafc4_row1_col2" class="data row1 col2" >1.274.641.198,66</td>
#     </tr>
#     <tr>
#       <th id="T_eafc4_level0_row2" class="row_heading level0 row2" >Investimento</th>
#       <td id="T_eafc4_row2_col0" class="data row2 col0" >30.890.574.881,98</td>
#       <td id="T_eafc4_row2_col1" class="data row2 col1" >40.071.310.662,46</td>
#       <td id="T_eafc4_row2_col2" class="data row2 col2" >22.034.164.357,93</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Modalidade

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_MODALIDADE', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_MODALIDADE', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_MODALIDADE', 'MODALIDADE'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                        % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_MODALIDADE
# Não                                    99.30                    98.18
# Sim                                     0.70                     1.82
# <style type="text/css">
# #T_a5c27 th.row_heading {
#   text-align: left;
# }
# #T_a5c27 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_a5c27" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_a5c27_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_a5c27_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_a5c27_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_MODALIDADE</th>
#       <th class="index_name level1" >MODALIDADE</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5c27_level0_row0" class="row_heading level0 row0" rowspan="29">Não</th>
#       <th id="T_a5c27_level1_row0" class="row_heading level1 row0" >AQUICULTURA</th>
#       <td id="T_a5c27_row0_col0" class="data row0 col0" >210.967.635,40</td>
#       <td id="T_a5c27_row0_col1" class="data row0 col1" >255.044.845,17</td>
#       <td id="T_a5c27_row0_col2" class="data row0 col2" >236.875.092,75</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row1" class="row_heading level1 row1" >AQUISIÇÃO DE ANIMAIS</th>
#       <td id="T_a5c27_row1_col0" class="data row1 col0" >7.955.378.709,46</td>
#       <td id="T_a5c27_row1_col1" class="data row1 col1" >10.153.348.223,88</td>
#       <td id="T_a5c27_row1_col2" class="data row1 col2" >5.342.206.141,41</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row2" class="row_heading level1 row2" >AQUISIÇÃO DE ANIMAIS DE SERVIÇO</th>
#       <td id="T_a5c27_row2_col0" class="data row2 col0" >784.900,00</td>
#       <td id="T_a5c27_row2_col1" class="data row2 col1" >80.860,00</td>
#       <td id="T_a5c27_row2_col2" class="data row2 col2" >3.000,00</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row3" class="row_heading level1 row3" >AQUISIÇÃO DE ANIMAIS DE SERVIÇO (USO AGRICULTURA)</th>
#       <td id="T_a5c27_row3_col0" class="data row3 col0" >25.030.373,04</td>
#       <td id="T_a5c27_row3_col1" class="data row3 col1" >22.063.275,60</td>
#       <td id="T_a5c27_row3_col2" class="data row3 col2" >18.378.756,70</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row4" class="row_heading level1 row4" >AQUISIÇÃO DE ATIVOS OPERACIONAIS</th>
#       <td id="T_a5c27_row4_col0" class="data row4 col0" >1.863.623.994,49</td>
#       <td id="T_a5c27_row4_col1" class="data row4 col1" >3.350.147.743,98</td>
#       <td id="T_a5c27_row4_col2" class="data row4 col2" >1.646.197.037,69</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row5" class="row_heading level1 row5" >AQUISIÇÃO DE INSUMOS PARA INDÚSTRIA FAMILIAR</th>
#       <td id="T_a5c27_row5_col0" class="data row5 col0" >74.850.140,01</td>
#       <td id="T_a5c27_row5_col1" class="data row5 col1" >95.652.368,40</td>
#       <td id="T_a5c27_row5_col2" class="data row5 col2" >76.788.032,56</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row6" class="row_heading level1 row6" >AQUISIÇÃO DE PROPRIEDADES RURAIS</th>
#       <td id="T_a5c27_row6_col0" class="data row6 col0" >236.967.912,61</td>
#       <td id="T_a5c27_row6_col1" class="data row6 col1" >285.712.743,41</td>
#       <td id="T_a5c27_row6_col2" class="data row6 col2" >201.600.965,13</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row7" class="row_heading level1 row7" >AQUISIÇÃO DE VEÍCULOS</th>
#       <td id="T_a5c27_row7_col0" class="data row7 col0" >348.231.279,61</td>
#       <td id="T_a5c27_row7_col1" class="data row7 col1" >685.038.269,08</td>
#       <td id="T_a5c27_row7_col2" class="data row7 col2" >325.211.298,36</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row8" class="row_heading level1 row8" >AQUISIÇÃO E MANUTENÇÃO DE ANIMAIS</th>
#       <td id="T_a5c27_row8_col0" class="data row8 col0" >5.278.402.411,91</td>
#       <td id="T_a5c27_row8_col1" class="data row8 col1" >5.637.260.813,00</td>
#       <td id="T_a5c27_row8_col2" class="data row8 col2" >3.393.767.291,75</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row9" class="row_heading level1 row9" >ATENDIMENTO A COOPERADOS (MCR 5-2)</th>
#       <td id="T_a5c27_row9_col0" class="data row9 col0" >108.605.747,73</td>
#       <td id="T_a5c27_row9_col1" class="data row9 col1" >11.808.250,00</td>
#       <td id="T_a5c27_row9_col2" class="data row9 col2" >14.000.000,00</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row10" class="row_heading level1 row10" >AVICULTURA</th>
#       <td id="T_a5c27_row10_col0" class="data row10 col0" >85.878.191,43</td>
#       <td id="T_a5c27_row10_col1" class="data row10 col1" >99.820.838,56</td>
#       <td id="T_a5c27_row10_col2" class="data row10 col2" >78.335.653,46</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row11" class="row_heading level1 row11" >BENEFICIAMENTO OU INDUSTRIALIZAÇÃO</th>
#       <td id="T_a5c27_row11_col0" class="data row11 col0" >1.873.248.365,85</td>
#       <td id="T_a5c27_row11_col1" class="data row11 col1" >1.438.052.131,53</td>
#       <td id="T_a5c27_row11_col2" class="data row11 col2" >1.250.046.198,66</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row12" class="row_heading level1 row12" >BOVINOCULTURA</th>
#       <td id="T_a5c27_row12_col0" class="data row12 col0" >7.919.114.929,49</td>
#       <td id="T_a5c27_row12_col1" class="data row12 col1" >9.429.083.717,35</td>
#       <td id="T_a5c27_row12_col2" class="data row12 col2" >6.948.574.766,46</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row13" class="row_heading level1 row13" >BUBALINOCULTURA</th>
#       <td id="T_a5c27_row13_col0" class="data row13 col0" >8.204.217,33</td>
#       <td id="T_a5c27_row13_col1" class="data row13 col1" >6.425.180,06</td>
#       <td id="T_a5c27_row13_col2" class="data row13 col2" >4.882.754,53</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row14" class="row_heading level1 row14" >CAPRINOCULTURA</th>
#       <td id="T_a5c27_row14_col0" class="data row14 col0" >12.833.029,42</td>
#       <td id="T_a5c27_row14_col1" class="data row14 col1" >37.216.205,42</td>
#       <td id="T_a5c27_row14_col2" class="data row14 col2" >9.043.741,16</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row15" class="row_heading level1 row15" >CUNICULTURA E DEMAIS ROEDORES</th>
#       <td id="T_a5c27_row15_col0" class="data row15 col0" >262.000,00</td>
#       <td id="T_a5c27_row15_col1" class="data row15 col1" >300.000,00</td>
#       <td id="T_a5c27_row15_col2" class="data row15 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row16" class="row_heading level1 row16" >EQUINOCULTURA</th>
#       <td id="T_a5c27_row16_col0" class="data row16 col0" >443.268,69</td>
#       <td id="T_a5c27_row16_col1" class="data row16 col1" >519.006,01</td>
#       <td id="T_a5c27_row16_col2" class="data row16 col2" >410.233,41</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row17" class="row_heading level1 row17" >FORMAÇÃO DE CULTURAS PERENES</th>
#       <td id="T_a5c27_row17_col0" class="data row17 col0" >1.647.036.042,17</td>
#       <td id="T_a5c27_row17_col1" class="data row17 col1" >2.132.841.623,95</td>
#       <td id="T_a5c27_row17_col2" class="data row17 col2" >1.190.659.514,82</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row18" class="row_heading level1 row18" >IMPLANTAÇÃO E MELHORAMENTO</th>
#       <td id="T_a5c27_row18_col0" class="data row18 col0" >62.359.756,34</td>
#       <td id="T_a5c27_row18_col1" class="data row18 col1" >258.639.598,08</td>
#       <td id="T_a5c27_row18_col2" class="data row18 col2" >827.600.989,84</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row19" class="row_heading level1 row19" >INTEGRALIZAÇÃO DE COTAS PARTES</th>
#       <td id="T_a5c27_row19_col0" class="data row19 col0" >427.102.072,86</td>
#       <td id="T_a5c27_row19_col1" class="data row19 col1" >467.263.191,43</td>
#       <td id="T_a5c27_row19_col2" class="data row19 col2" >214.774.379,39</td>
#     </tr>
#     <tr>
#       <th id="T_a5c27_level1_row20" class="row_heading

# %% [markdown]
# ### Produto

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_PRODUTO', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_PRODUTO', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_PRODUTO', 'PRODUTO'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                     % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_PRODUTO
# Não                                 96.83                    89.41
# Sim                                  3.17                    10.59
# <style type="text/css">
# #T_99f0a th.row_heading {
#   text-align: left;
# }
# #T_99f0a th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_99f0a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_99f0a_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_99f0a_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_99f0a_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_PRODUTO</th>
#       <th class="index_name level1" >PRODUTO</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99f0a_level0_row0" class="row_heading level0 row0" rowspan="289">Não</th>
#       <th id="T_99f0a_level1_row0" class="row_heading level1 row0" >ABACATE</th>
#       <td id="T_99f0a_row0_col0" class="data row0 col0" >13.815.173,50</td>
#       <td id="T_99f0a_row0_col1" class="data row0 col1" >16.880.552,71</td>
#       <td id="T_99f0a_row0_col2" class="data row0 col2" >6.783.897,29</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row1" class="row_heading level1 row1" >ABERTURA DE GLEBAS RURAIS</th>
#       <td id="T_99f0a_row1_col0" class="data row1 col0" >106.947.556,55</td>
#       <td id="T_99f0a_row1_col1" class="data row1 col1" >107.116.795,51</td>
#       <td id="T_99f0a_row1_col2" class="data row1 col2" >55.357.882,56</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row2" class="row_heading level1 row2" >ABOBRINHA</th>
#       <td id="T_99f0a_row2_col0" class="data row2 col0" >1.132.675,30</td>
#       <td id="T_99f0a_row2_col1" class="data row2 col1" >1.924.718,41</td>
#       <td id="T_99f0a_row2_col2" class="data row2 col2" >1.016.619,74</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row3" class="row_heading level1 row3" >ABÓBORA-MORANGA</th>
#       <td id="T_99f0a_row3_col0" class="data row3 col0" >30.088.099,97</td>
#       <td id="T_99f0a_row3_col1" class="data row3 col1" >59.670.160,78</td>
#       <td id="T_99f0a_row3_col2" class="data row3 col2" >6.734.818,72</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row4" class="row_heading level1 row4" >ACELGA</th>
#       <td id="T_99f0a_row4_col0" class="data row4 col0" >0,00</td>
#       <td id="T_99f0a_row4_col1" class="data row4 col1" >10.200,00</td>
#       <td id="T_99f0a_row4_col2" class="data row4 col2" >15.000,00</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row5" class="row_heading level1 row5" >ACEROLA</th>
#       <td id="T_99f0a_row5_col0" class="data row5 col0" >2.783.137,32</td>
#       <td id="T_99f0a_row5_col1" class="data row5 col1" >3.064.205,98</td>
#       <td id="T_99f0a_row5_col2" class="data row5 col2" >3.231.305,13</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row6" class="row_heading level1 row6" >ACÁCIA NEGRA</th>
#       <td id="T_99f0a_row6_col0" class="data row6 col0" >0,00</td>
#       <td id="T_99f0a_row6_col1" class="data row6 col1" >1.128.738,33</td>
#       <td id="T_99f0a_row6_col2" class="data row6 col2" >344.401,25</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row7" class="row_heading level1 row7" >ADUBAÇÃO INTENSIVA DO SOLO</th>
#       <td id="T_99f0a_row7_col0" class="data row7 col0" >970.506.835,82</td>
#       <td id="T_99f0a_row7_col1" class="data row7 col1" >794.163.897,07</td>
#       <td id="T_99f0a_row7_col2" class="data row7 col2" >392.430.452,98</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row8" class="row_heading level1 row8" >ADUBAÇÃO ORGÂNICA/MINERAL, CALAGEM, SUBSTRATOS INERTES(PEDRA, AREIA, VERMICULITA, SILTE, ARGILA ETC)</th>
#       <td id="T_99f0a_row8_col0" class="data row8 col0" >111.409.873,31</td>
#       <td id="T_99f0a_row8_col1" class="data row8 col1" >39.558.076,02</td>
#       <td id="T_99f0a_row8_col2" class="data row8 col2" >12.713.936,37</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row9" class="row_heading level1 row9" >AGAVE (SISAL)</th>
#       <td id="T_99f0a_row9_col0" class="data row9 col0" >3.053.199,18</td>
#       <td id="T_99f0a_row9_col1" class="data row9 col1" >2.107.587,99</td>
#       <td id="T_99f0a_row9_col2" class="data row9 col2" >1.080.888,38</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row10" class="row_heading level1 row10" >AGRIÃO</th>
#       <td id="T_99f0a_row10_col0" class="data row10 col0" >533.532,92</td>
#       <td id="T_99f0a_row10_col1" class="data row10 col1" >468.894,06</td>
#       <td id="T_99f0a_row10_col2" class="data row10 col2" >412.443,39</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row11" class="row_heading level1 row11" >AGROINDÚSTRIA</th>
#       <td id="T_99f0a_row11_col0" class="data row11 col0" >243.679.512,00</td>
#       <td id="T_99f0a_row11_col1" class="data row11 col1" >194.768.183,72</td>
#       <td id="T_99f0a_row11_col2" class="data row11 col2" >94.883.209,32</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row12" class="row_heading level1 row12" >ALCACHOFRA</th>
#       <td id="T_99f0a_row12_col0" class="data row12 col0" >120.127,12</td>
#       <td id="T_99f0a_row12_col1" class="data row12 col1" >123.207,31</td>
#       <td id="T_99f0a_row12_col2" class="data row12 col2" >79.503,81</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row13" class="row_heading level1 row13" >ALFACE</th>
#       <td id="T_99f0a_row13_col0" class="data row13 col0" >26.221.437,74</td>
#       <td id="T_99f0a_row13_col1" class="data row13 col1" >29.431.178,39</td>
#       <td id="T_99f0a_row13_col2" class="data row13 col2" >19.561.422,41</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row14" class="row_heading level1 row14" >ALFAFA</th>
#       <td id="T_99f0a_row14_col0" class="data row14 col0" >2.899.087,20</td>
#       <td id="T_99f0a_row14_col1" class="data row14 col1" >3.462.361,87</td>
#       <td id="T_99f0a_row14_col2" class="data row14 col2" >2.789.450,83</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row15" class="row_heading level1 row15" >ALGODÃO</th>
#       <td id="T_99f0a_row15_col0" class="data row15 col0" >247.000,00</td>
#       <td id="T_99f0a_row15_col1" class="data row15 col1" >4.000,00</td>
#       <td id="T_99f0a_row15_col2" class="data row15 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row16" class="row_heading level1 row16" >ALHO</th>
#       <td id="T_99f0a_row16_col0" class="data row16 col0" >31.923.229,03</td>
#       <td id="T_99f0a_row16_col1" class="data row16 col1" >29.431.952,15</td>
#       <td id="T_99f0a_row16_col2" class="data row16 col2" >26.015.005,39</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row17" class="row_heading level1 row17" >ALHO PORÓ</th>
#       <td id="T_99f0a_row17_col0" class="data row17 col0" >2.090.864,40</td>
#       <td id="T_99f0a_row17_col1" class="data row17 col1" >3.903.931,36</td>
#       <td id="T_99f0a_row17_col2" class="data row17 col2" >3.156.050,22</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row18" class="row_heading level1 row18" >AMEIXA</th>
#       <td id="T_99f0a_row18_col0" class="data row18 col0" >33.954.874,25</td>
#       <td id="T_99f0a_row18_col1" class="data row18 col1" >39.144.397,48</td>
#       <td id="T_99f0a_row18_col2" class="data row18 col2" >40.131.885,08</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row19" class="row_heading level1 row19" >AMENDOIM</th>
#       <td id="T_99f0a_row19_col0" class="data row19 col0" >4.023.352,34</td>
#       <td id="T_99f0a_row19_col1" class="data row19 col1" >7.202.879,40</td>
#       <td id="T_99f0a_row19_col2" class="data row19 col2" >3.029.489,15</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row20" class="row_heading level1 row20" >AMORA</th>
#       <td id="T_99f0a_row20_col0" class="data row20 col0" >3.939.801,73</td>
#       <td id="T_99f0a_row20_col1" class="data row20 col1" >2.668.194,32</td>
#       <td id="T_99f0a_row20_col2" class="data row20 col2" >1.541.480,20</td>
#     </tr>
#     <tr>
#       <th id="T_99f0a_level1_row21" class="row_heading level

# %% [markdown]
# ### Cesta Safra

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_CESTA_SAFRA', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_CESTA_SAFRA', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_CESTA_SAFRA', 'CESTA_SAFRA'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                         % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_CESTA_SAFRA
# Não                                     94.24                    93.91
# Sim                                      5.76                     6.09
# <style type="text/css">
# #T_56af7 th.row_heading {
#   text-align: left;
# }
# #T_56af7 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_56af7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_56af7_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_56af7_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_56af7_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_CESTA_SAFRA</th>
#       <th class="index_name level1" >CESTA_SAFRA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56af7_level0_row0" class="row_heading level0 row0" rowspan="5">Não</th>
#       <th id="T_56af7_level1_row0" class="row_heading level1 row0" >Ano Civil / Ano de Exploração</th>
#       <td id="T_56af7_row0_col0" class="data row0 col0" >46.818.270.227,78</td>
#       <td id="T_56af7_row0_col1" class="data row0 col1" >57.316.502.174,82</td>
#       <td id="T_56af7_row0_col2" class="data row0 col2" >34.175.464.695,55</td>
#     </tr>
#     <tr>
#       <th id="T_56af7_level1_row1" class="row_heading level1 row1" >Irrigadas</th>
#       <td id="T_56af7_row1_col0" class="data row1 col0" >1.599.339.530,99</td>
#       <td id="T_56af7_row1_col1" class="data row1 col1" >456.974.832,71</td>
#       <td id="T_56af7_row1_col2" class="data row1 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_56af7_level1_row2" class="row_heading level1 row2" >Safra de Inverno (3ª Safra)</th>
#       <td id="T_56af7_row2_col0" class="data row2 col0" >2.580.575.710,65</td>
#       <td id="T_56af7_row2_col1" class="data row2 col1" >1.898.426.113,45</td>
#       <td id="T_56af7_row2_col2" class="data row2 col2" >1.324.520.175,93</td>
#     </tr>
#     <tr>
#       <th id="T_56af7_level1_row3" class="row_heading level1 row3" >Safra de Verão (1ª Safra)</th>
#       <td id="T_56af7_row3_col0" class="data row3 col0" >9.569.835.408,40</td>
#       <td id="T_56af7_row3_col1" class="data row3 col1" >9.081.288.427,38</td>
#       <td id="T_56af7_row3_col2" class="data row3 col2" >6.549.690.769,21</td>
#     </tr>
#     <tr>
#       <th id="T_56af7_level1_row4" class="row_heading level1 row4" >Safrinha (2ª Safra)</th>
#       <td id="T_56af7_row4_col0" class="data row4 col0" >1.290.133.493,77</td>
#       <td id="T_56af7_row4_col1" class="data row4 col1" >1.277.474.375,58</td>
#       <td id="T_56af7_row4_col2" class="data row4 col2" >441.531.000,45</td>
#     </tr>
#     <tr>
#       <th id="T_56af7_level0_row5" class="row_heading level0 row5" >Sim</th>
#       <th id="T_56af7_level1_row5" class="row_heading level1 row5" >Fruticultura / Olericultura</th>
#       <td id="T_56af7_row5_col0" class="data row5 col0" >3.262.834.618,62</td>
#       <td id="T_56af7_row5_col1" class="data row5 col1" >4.190.309.307,69</td>
#       <td id="T_56af7_row5_col2" class="data row5 col2" >3.209.246.036,47</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Consórcio

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_CONSORCIO', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_CONSORCIO', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_CONSORCIO','CONSORCIO'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                       % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_CONSORCIO
# Não                                   99.92                    99.92
# Sim                                    0.08                     0.08
# <style type="text/css">
# #T_7e188 th.row_heading {
#   text-align: left;
# }
# #T_7e188 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_7e188" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_7e188_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_7e188_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_7e188_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_CONSORCIO</th>
#       <th class="index_name level1" >CONSORCIO</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e188_level0_row0" class="row_heading level0 row0" rowspan="2">Não</th>
#       <th id="T_7e188_level1_row0" class="row_heading level1 row0" >Não consorciado</th>
#       <td id="T_7e188_row0_col0" class="data row0 col0" >33.811.141.704,61</td>
#       <td id="T_7e188_row0_col1" class="data row0 col1" >37.895.382.802,23</td>
#       <td id="T_7e188_row0_col2" class="data row0 col2" >21.947.280.923,28</td>
#     </tr>
#     <tr>
#       <th id="T_7e188_level1_row1" class="row_heading level1 row1" >Valor inválido</th>
#       <td id="T_7e188_row1_col0" class="data row1 col0" >31.261.114.505,03</td>
#       <td id="T_7e188_row1_col1" class="data row1 col1" >36.263.257.899,04</td>
#       <td id="T_7e188_row1_col2" class="data row1 col2" >23.725.167.187,66</td>
#     </tr>
#     <tr>
#       <th id="T_7e188_level0_row2" class="row_heading level0 row2" >Sim</th>
#       <th id="T_7e188_level1_row2" class="row_heading level1 row2" >Consorciado</th>
#       <td id="T_7e188_row2_col0" class="data row2 col0" >48.732.780,57</td>
#       <td id="T_7e188_row2_col1" class="data row2 col1" >62.334.530,36</td>
#       <td id="T_7e188_row2_col2" class="data row2 col2" >28.004.566,67</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Irrigação

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_IRRIGACAO', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_IRRIGACAO', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_TIPO_IRRIGACAO','CD_TIPO_IRRIGACAO', 'DESCRICAO_TIPO_IRRIGACAO'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                            % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_TIPO_IRRIGACAO
# Não                                        76.63                    86.88
# Sim                                        23.37                    13.12
# <style type="text/css">
# #T_0ec5d th.row_heading {
#   text-align: left;
# }
# #T_0ec5d th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_0ec5d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_0ec5d_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_0ec5d_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_0ec5d_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_TIPO_IRRIGACAO</th>
#       <th class="index_name level1" >CD_TIPO_IRRIGACAO</th>
#       <th class="index_name level2" >DESCRICAO_TIPO_IRRIGACAO</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ec5d_level0_row0" class="row_heading level0 row0" rowspan="8">Não</th>
#       <th id="T_0ec5d_level1_row0" class="row_heading level1 row0" >0</th>
#       <th id="T_0ec5d_level2_row0" class="row_heading level2 row0" >Não se aplica</th>
#       <td id="T_0ec5d_row0_col0" class="data row0 col0" >45.887.087.894,94</td>
#       <td id="T_0ec5d_row0_col1" class="data row0 col1" >57.183.578.794,71</td>
#       <td id="T_0ec5d_row0_col2" class="data row0 col2" >35.343.568.842,20</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row1" class="row_heading level1 row1" >4</th>
#       <th id="T_0ec5d_level2_row1" class="row_heading level2 row1" >Aspersão</th>
#       <td id="T_0ec5d_row1_col0" class="data row1 col0" >641.970.456,59</td>
#       <td id="T_0ec5d_row1_col1" class="data row1 col1" >750.721.733,23</td>
#       <td id="T_0ec5d_row1_col2" class="data row1 col2" >697.804.892,94</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row2" class="row_heading level1 row2" >6</th>
#       <th id="T_0ec5d_level2_row2" class="row_heading level2 row2" >Pivô</th>
#       <td id="T_0ec5d_row2_col0" class="data row2 col0" >48.668.788,60</td>
#       <td id="T_0ec5d_row2_col1" class="data row2 col1" >48.822.354,22</td>
#       <td id="T_0ec5d_row2_col2" class="data row2 col2" >27.078.817,78</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row3" class="row_heading level1 row3" >7</th>
#       <th id="T_0ec5d_level2_row3" class="row_heading level2 row3" >Canhão</th>
#       <td id="T_0ec5d_row3_col0" class="data row3 col0" >20.380.189,10</td>
#       <td id="T_0ec5d_row3_col1" class="data row3 col1" >23.178.991,99</td>
#       <td id="T_0ec5d_row3_col2" class="data row3 col2" >31.154.938,61</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row4" class="row_heading level1 row4" >8</th>
#       <th id="T_0ec5d_level2_row4" class="row_heading level2 row4" >Auto-Propelido</th>
#       <td id="T_0ec5d_row4_col0" class="data row4 col0" >2.845.405,90</td>
#       <td id="T_0ec5d_row4_col1" class="data row4 col1" >6.126.823,24</td>
#       <td id="T_0ec5d_row4_col2" class="data row4 col2" >10.757.055,34</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row5" class="row_heading level1 row5" >9</th>
#       <th id="T_0ec5d_level2_row5" class="row_heading level2 row5" >Sulcos</th>
#       <td id="T_0ec5d_row5_col0" class="data row5 col0" >37.198.456,45</td>
#       <td id="T_0ec5d_row5_col1" class="data row5 col1" >32.989.716,37</td>
#       <td id="T_0ec5d_row5_col2" class="data row5 col2" >17.260.659,84</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row6" class="row_heading level1 row6" >10</th>
#       <th id="T_0ec5d_level2_row6" class="row_heading level2 row6" >Inundação</th>
#       <td id="T_0ec5d_row6_col0" class="data row6 col0" >311.728.619,40</td>
#       <td id="T_0ec5d_row6_col1" class="data row6 col1" >346.419.862,61</td>
#       <td id="T_0ec5d_row6_col2" class="data row6 col2" >291.661.445,11</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row7" class="row_heading level1 row7" >11</th>
#       <th id="T_0ec5d_level2_row7" class="row_heading level2 row7" >Irrigação com cobertura contra a seca MCR 12-2-3-c""</th>
#       <td id="T_0ec5d_row7_col0" class="data row7 col0" >16.094.780,70</td>
#       <td id="T_0ec5d_row7_col1" class="data row7 col1" >8.520.819,95</td>
#       <td id="T_0ec5d_row7_col2" class="data row7 col2" >4.796.769,43</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level0_row8" class="row_heading level0 row8" rowspan="4">Sim</th>
#       <th id="T_0ec5d_level1_row8" class="row_heading level1 row8" >1</th>
#       <th id="T_0ec5d_level2_row8" class="row_heading level2 row8" >Não Irrigado</th>
#       <td id="T_0ec5d_row8_col0" class="data row8 col0" >17.170.696.892,76</td>
#       <td id="T_0ec5d_row8_col1" class="data row8 col1" >14.715.251.153,48</td>
#       <td id="T_0ec5d_row8_col2" class="data row8 col2" >8.494.563.693,56</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row9" class="row_heading level1 row9" >2</th>
#       <th id="T_0ec5d_level2_row9" class="row_heading level2 row9" >Gotejamento</th>
#       <td id="T_0ec5d_row9_col0" class="data row9 col0" >771.230.143,77</td>
#       <td id="T_0ec5d_row9_col1" class="data row9 col1" >974.211.164,02</td>
#       <td id="T_0ec5d_row9_col2" class="data row9 col2" >690.147.390,75</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row10" class="row_heading level1 row10" >3</th>
#       <th id="T_0ec5d_level2_row10" class="row_heading level2 row10" >Micro-aspersão</th>
#       <td id="T_0ec5d_row10_col0" class="data row10 col0" >212.968.959,22</td>
#       <td id="T_0ec5d_row10_col1" class="data row10 col1" >131.081.107,81</td>
#       <td id="T_0ec5d_row10_col2" class="data row10 col2" >91.603.172,05</td>
#     </tr>
#     <tr>
#       <th id="T_0ec5d_level1_row11" class="row_heading level1 row11" >5</th>
#       <th id="T_0ec5d_level2_row11" class="row_heading level2 row11" >Xique-Xique</th>
#       <td id="T_0ec5d_row11_col0" class="data row11 col0" >118.402,78</td>
#       <td id="T_0ec5d_row11_col1" class="data row11 col1" >72.710,00</td>
#       <td id="T_0ec5d_row11_col2" class="data row11 col2" >55.000,00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Agricultura

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_AGRICULTURA', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_AGRICULTURA', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_TIPO_AGRICULTURA','CD_TIPO_AGRICULTURA', 'DESCRICAO_TIPO_AGRICULTURA'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                              % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_TIPO_AGRICULTURA
# Não                                          93.77                    96.23
# Sim                                           6.23                     3.77
# <style type="text/css">
# #T_72975 th.row_heading {
#   text-align: left;
# }
# #T_72975 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_72975" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_72975_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_72975_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_72975_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_TIPO_AGRICULTURA</th>
#       <th class="index_name level1" >CD_TIPO_AGRICULTURA</th>
#       <th class="index_name level2" >DESCRICAO_TIPO_AGRICULTURA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72975_level0_row0" class="row_heading level0 row0" rowspan="4">Não</th>
#       <th id="T_72975_level1_row0" class="row_heading level1 row0" >0</th>
#       <th id="T_72975_level2_row0" class="row_heading level2 row0" >Não se aplica</th>
#       <td id="T_72975_row0_col0" class="data row0 col0" >47.448.981.323,26</td>
#       <td id="T_72975_row0_col1" class="data row0 col1" >58.028.532.876,82</td>
#       <td id="T_72975_row0_col2" class="data row0 col2" >34.873.164.065,63</td>
#     </tr>
#     <tr>
#       <th id="T_72975_level1_row1" class="row_heading level1 row1" >3</th>
#       <th id="T_72975_level2_row1" class="row_heading level2 row1" >Convencional</th>
#       <td id="T_72975_row1_col0" class="data row1 col0" >7.270.079.863,36</td>
#       <td id="T_72975_row1_col1" class="data row1 col1" >6.846.690.254,70</td>
#       <td id="T_72975_row1_col2" class="data row1 col2" >4.739.512.076,85</td>
#     </tr>
#     <tr>
#       <th id="T_72975_level1_row2" class="row_heading level1 row2" >6</th>
#       <th id="T_72975_level2_row2" class="row_heading level2 row2" >Floresta Plantada</th>
#       <td id="T_72975_row2_col0" class="data row2 col0" >1.446.381,95</td>
#       <td id="T_72975_row2_col1" class="data row2 col1" >1.292.314,99</td>
#       <td id="T_72975_row2_col2" class="data row2 col2" >19.700,00</td>
#     </tr>
#     <tr>
#       <th id="T_72975_level1_row3" class="row_heading level1 row3" >7</th>
#       <th id="T_72975_level2_row3" class="row_heading level2 row3" >Transgênica</th>
#       <td id="T_72975_row3_col0" class="data row3 col0" >6.061.669.152,42</td>
#       <td id="T_72975_row3_col1" class="data row3 col1" >5.122.045.481,64</td>
#       <td id="T_72975_row3_col2" class="data row3 col2" >3.128.642.450,58</td>
#     </tr>
#     <tr>
#       <th id="T_72975_level0_row4" class="row_heading level0 row4" rowspan="4">Sim</th>
#       <th id="T_72975_level1_row4" class="row_heading level1 row4" >4</th>
#       <th id="T_72975_level2_row4" class="row_heading level2 row4" >Floresta Nativa</th>
#       <td id="T_72975_row4_col0" class="data row4 col0" >1.232.224,05</td>
#       <td id="T_72975_row4_col1" class="data row4 col1" >754.767,18</td>
#       <td id="T_72975_row4_col2" class="data row4 col2" >432.346,12</td>
#     </tr>
#     <tr>
#       <th id="T_72975_level1_row5" class="row_heading level1 row5" >5</th>
#       <th id="T_72975_level2_row5" class="row_heading level2 row5" >Plantio Direto</th>
#       <td id="T_72975_row5_col0" class="data row5 col0" >4.307.907.827,64</td>
#       <td id="T_72975_row5_col1" class="data row5 col1" >4.178.989.932,32</td>
#       <td id="T_72975_row5_col2" class="data row5 col2" >2.935.628.538,99</td>
#     </tr>
#     <tr>
#       <th id="T_72975_level1_row6" class="row_heading level1 row6" >8</th>
#       <th id="T_72975_level2_row6" class="row_heading level2 row6" >Agroecológica</th>
#       <td id="T_72975_row6_col0" class="data row6 col0" >7.227.057,81</td>
#       <td id="T_72975_row6_col1" class="data row6 col1" >10.162.307,29</td>
#       <td id="T_72975_row6_col2" class="data row6 col2" >6.561.566,77</td>
#     </tr>
#     <tr>
#       <th id="T_72975_level1_row7" class="row_heading level1 row7" >9</th>
#       <th id="T_72975_level2_row7" class="row_heading level2 row7" >Orgânica</th>
#       <td id="T_72975_row7_col0" class="data row7 col0" >22.445.159,72</td>
#       <td id="T_72975_row7_col1" class="data row7 col1" >32.507.296,69</td>
#       <td id="T_72975_row7_col2" class="data row7 col2" >16.491.932,67</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Cultura

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_CULTURA', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_CULTURA', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_TIPO_CULTURA','CD_TIPO_CULTURA', 'DESCRICAO_TIPO_CULTURA'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                          % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_TIPO_CULTURA
# Não                                      98.42                    99.03
# Sim                                       1.58                     0.97
# <style type="text/css">
# #T_b658a th.row_heading {
#   text-align: left;
# }
# #T_b658a th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_b658a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_b658a_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_b658a_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_b658a_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_TIPO_CULTURA</th>
#       <th class="index_name level1" >CD_TIPO_CULTURA</th>
#       <th class="index_name level2" >DESCRICAO_TIPO_CULTURA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b658a_level0_row0" class="row_heading level0 row0" rowspan="2">Não</th>
#       <th id="T_b658a_level1_row0" class="row_heading level1 row0" >2</th>
#       <th id="T_b658a_level2_row0" class="row_heading level2 row0" >Permanente</th>
#       <td id="T_b658a_row0_col0" class="data row0 col0" >4.953.716.813,24</td>
#       <td id="T_b658a_row0_col1" class="data row0 col1" >5.581.366.411,32</td>
#       <td id="T_b658a_row0_col2" class="data row0 col2" >3.547.809.821,14</td>
#     </tr>
#     <tr>
#       <th id="T_b658a_level1_row1" class="row_heading level1 row1" >3</th>
#       <th id="T_b658a_level2_row1" class="row_heading level2 row1" >Demais culturas</th>
#       <td id="T_b658a_row1_col0" class="data row1 col0" >28.150.547.706,41</td>
#       <td id="T_b658a_row1_col1" class="data row1 col1" >31.542.366.731,05</td>
#       <td id="T_b658a_row1_col2" class="data row1 col2" >17.664.734.740,51</td>
#     </tr>
#     <tr>
#       <th id="T_b658a_level0_row2" class="row_heading level0 row2" >Sim</th>
#       <th id="T_b658a_level1_row2" class="row_heading level1 row2" >1</th>
#       <th id="T_b658a_level2_row2" class="row_heading level2 row2" >Olericultura</th>
#       <td id="T_b658a_row2_col0" class="data row2 col0" >961.982.064,04</td>
#       <td id="T_b658a_row2_col1" class="data row2 col1" >1.025.734.745,39</td>
#       <td id="T_b658a_row2_col2" class="data row2 col2" >940.913.114,29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Intgr Consor

# %%
# 1) % por volume de crédito
pct_por_credito = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_INTGR_CONSOR', dropna=False)['VL_PARC_CREDITO']
      .sum()
      .pipe(lambda s: s / s.sum() * 100)
)

# 2) % por CPFs/CNPJs únicos
pct_por_uniq = (
    df_pronaf_semana_inovacao
      .groupby('FLAG_VERDE_TIPO_INTGR_CONSOR', dropna=False)['CD_CPF_CNPJ']
      .nunique()
      .pipe(lambda s: s / s.sum() * 100)
)

# Junta e imprime arredondado
resultado = pd.DataFrame({
    '% por VL_PARC_CREDITO': pct_por_credito,
    '% por CPFs/CNPJs únicos': pct_por_uniq
}).round(2)

print(resultado)

df_pivotado = df_pronaf_semana_inovacao.pivot_table(
    index=['FLAG_VERDE_TIPO_INTGR_CONSOR','CD_TIPO_INTGR_CONSOR', 'DESCRICAO_TIPO_INTGR_CONSOR'],
    columns='ANO',
    values='VL_PARC_CREDITO',
    aggfunc='sum',
    fill_value=0
)

# Estilo: números pt-BR e descrição à esquerda (sem criar outro DF)
sty = (
    df_pivotado
      .style
      .format(lambda v: f'{v:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))
      .set_table_styles([
          {'selector': 'th.row_heading', 'props': [('text-align', 'left')]},   # índice à esquerda
          {'selector': 'th.col_heading', 'props': [('text-align', 'center')]} # cabeçalhos ao centro
      ])
)
display(sty)
# Out:
#                               % por VL_PARC_CREDITO  % por CPFs/CNPJs únicos
# FLAG_VERDE_TIPO_INTGR_CONSOR
# Não                                           99.84                    99.65
# Sim                                            0.16                     0.35
# <style type="text/css">
# #T_82e32 th.row_heading {
#   text-align: left;
# }
# #T_82e32 th.col_heading {
#   text-align: center;
# }
# </style>
# <table id="T_82e32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >ANO</th>
#       <th id="T_82e32_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_82e32_level0_col1" class="col_heading level0 col1" >2024</th>
#       <th id="T_82e32_level0_col2" class="col_heading level0 col2" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FLAG_VERDE_TIPO_INTGR_CONSOR</th>
#       <th class="index_name level1" >CD_TIPO_INTGR_CONSOR</th>
#       <th class="index_name level2" >DESCRICAO_TIPO_INTGR_CONSOR</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82e32_level0_row0" class="row_heading level0 row0" rowspan="2">Não</th>
#       <th id="T_82e32_level1_row0" class="row_heading level1 row0" >0</th>
#       <th id="T_82e32_level2_row0" class="row_heading level2 row0" >Não se aplica</th>
#       <td id="T_82e32_row0_col0" class="data row0 col0" >47.585.700.468,29</td>
#       <td id="T_82e32_row0_col1" class="data row0 col1" >58.096.627.103,83</td>
#       <td id="T_82e32_row0_col2" class="data row0 col2" >34.928.286.533,02</td>
#     </tr>
#     <tr>
#       <th id="T_82e32_level1_row1" class="row_heading level1 row1" >2</th>
#       <th id="T_82e32_level2_row1" class="row_heading level2 row1" >Lavoura Solteira</th>
#       <td id="T_82e32_row1_col0" class="data row1 col0" >17.406.109.322,77</td>
#       <td id="T_82e32_row1_col1" class="data row1 col1" >16.010.282.375,40</td>
#       <td id="T_82e32_row1_col2" class="data row1 col2" >10.720.014.924,19</td>
#     </tr>
#     <tr>
#       <th id="T_82e32_level0_row2" class="row_heading level0 row2" rowspan="6">Sim</th>
#       <th id="T_82e32_level1_row2" class="row_heading level1 row2" >1</th>
#       <th id="T_82e32_level2_row2" class="row_heading level2 row2" >Consórcio</th>
#       <td id="T_82e32_row2_col0" class="data row2 col0" >58.334.819,05</td>
#       <td id="T_82e32_row2_col1" class="data row2 col1" >76.043.752,65</td>
#       <td id="T_82e32_row2_col2" class="data row2 col2" >30.884.672,58</td>
#     </tr>
#     <tr>
#       <th id="T_82e32_level1_row3" class="row_heading level1 row3" >3</th>
#       <th id="T_82e32_level2_row3" class="row_heading level2 row3" >Integração Lavoura Pecuária</th>
#       <td id="T_82e32_row3_col0" class="data row3 col0" >42.714.875,98</td>
#       <td id="T_82e32_row3_col1" class="data row3 col1" >28.956.282,61</td>
#       <td id="T_82e32_row3_col2" class="data row3 col2" >15.117.877,91</td>
#     </tr>
#     <tr>
#       <th id="T_82e32_level1_row4" class="row_heading level1 row4" >4</th>
#       <th id="T_82e32_level2_row4" class="row_heading level2 row4" >Sistemas Agroflorestais</th>
#       <td id="T_82e32_row4_col0" class="data row4 col0" >21.049.206,37</td>
#       <td id="T_82e32_row4_col1" class="data row4 col1" >6.466.134,59</td>
#       <td id="T_82e32_row4_col2" class="data row4 col2" >3.978.729,14</td>
#     </tr>
#     <tr>
#       <th id="T_82e32_level1_row5" class="row_heading level1 row5" >5</th>
#       <th id="T_82e32_level2_row5" class="row_heading level2 row5" >Integração Lavoura-Pecuária-Floresta/Sistema Agro-Silvo-Pastoril</th>
#       <td id="T_82e32_row5_col0" class="data row5 col0" >6.279.219,42</td>
#       <td id="T_82e32_row5_col1" class="data row5 col1" >1.323.848,25</td>
#       <td id="T_82e32_row5_col2" class="data row5 col2" >699.593,11</td>
#     </tr>
#     <tr>
#       <th id="T_82e32_level1_row6" class="row_heading level1 row6" >6</th>
#       <th id="T_82e32_level2_row6" class="row_heading level2 row6" >Integração Lavoura-Floresta</th>
#       <td id="T_82e32_row6_col0" class="data row6 col0" >426.728,33</td>
#       <td id="T_82e32_row6_col1" class="data row6 col1" >759.278,00</td>
#       <td id="T_82e32_row6_col2" class="data row6 col2" >636.719,30</td>
#     </tr>
#     <tr>
#       <th id="T_82e32_level1_row7" class="row_heading level1 row7" >7</th>
#       <th id="T_82e32_level2_row7" class="row_heading level2 row7" >Integração Pecuária-Floresta</th>
#       <td id="T_82e32_row7_col0" class="data row7 col0" >374.350,00</td>
#       <td id="T_82e32_row7_col1" class="data row7 col1" >516.456,30</td>
#       <td id="T_82e32_row7_col2" class="data row7 col2" >833.628,36</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Utilizando Funções de Consulta

# %% [markdown]
# ### consulta_pronaf_por_estado

# %%
# Crie uma função chamada 'consulta_pronaf_por_estado'.
# A função deve receber dois argumentos: um dataframe pandas 'df' e uma string 'cd_estado'.
# A função deve ter um type hint de retorno indicando que ela devolve uma string.

# Passo 1: Filtrar os dados
# Dentro da função, primeiro filtre o dataframe 'df'.
# O critério do filtro é manter apenas as linhas onde a coluna "CD_ESTADO" seja igual ao argumento 'cd_estado' convertido para letras maiúsculas.

# Passo 2: Lidar com estado não encontrado
# Adicione uma verificação: se o dataframe filtrado estiver vazio, a função deve retornar uma string de aviso, informando que nenhum dado foi encontrado para o estado.

# Passo 3: Agrupar e agregar
# Se o dataframe filtrado não estiver vazio, agrupe os dados pelas colunas "ANO" e "SEXO_BIOLOGICO".
# Após agrupar, calcule as seguintes agregações:
# - A SOMA da coluna "VL_PARC_CREDITO", e renomeie a coluna resultante para "Soma_VL_PARC_CREDITO".
# - A CONTAGEM da coluna "CD_CPF_CNPJ", e renomeie para "Quantidade_Operacoes".
# - A CONTAGEM DE VALORES ÚNICOS da coluna "CD_CPF_CNPJ", e renomeie para "Quantidade_Beneficiarios".
# Após a agregação, transforme o resultado de volta em um dataframe padrão.

# Passo 4: Formatar a saída
# Converta o dataframe agregado para uma string no formato Markdown.
# Na conversão para Markdown, especifique que o índice não deve ser incluído e que números de ponto flutuante devem ser formatados com duas casas decimais.

# Passo 5: Retornar o resultado final
# Por fim, a função deve retornar uma string formatada contendo um título, como "Resumo dos dados do PRONAF para o estado [NOME DO ESTADO]:", seguido por duas quebras de linha e a tabela em Markdown.

def consulta_pronaf_por_estado(df: pd.DataFrame, cd_estado: str) -> str:
    """Resumo do PRONAF por UF em Markdown."""
    df_estado = df[df["CD_ESTADO"] == cd_estado.upper()]

    if df_estado.empty:
        return (
            f"Nenhum dado encontrado para o estado '{cd_estado}'. "
            "Verifique o código UF."
        )

    resumo = (
        df_estado
        .groupby(["ANO", "SEXO_BIOLOGICO"])
        .agg(
            Soma_VL_PARC_CREDITO=("VL_PARC_CREDITO", "sum"),
            Quantidade_Operacoes=("CD_CPF_CNPJ", "count"),
            Quantidade_Beneficiarios=("CD_CPF_CNPJ", "nunique"),
        )
        .reset_index()
    )

    tabela = resumo.to_markdown(index=False, floatfmt=".2f")
    return f"Resumo dos dados do PRONAF para o estado {cd_estado.upper()}:\n\n{tabela}"

# %%
# testar a função consulta_pronaf_por_estado utilizando o estado do Minas Gerais
consulta_pronaf_por_estado(df_pronaf_semana_inovacao, 'AL')
# Out:
# 'Resumo dos dados do PRONAF para o estado AL:\n\n|   ANO | SEXO_BIOLOGICO   |   Soma_VL_PARC_CREDITO |   Quantidade_Operacoes |   Quantidade_Beneficiarios |\n|------:|:-----------------|-----------------------:|-----------------------:|---------------------------:|\n|  2023 | Feminino         |           186858922.89 |                  17672 |                      13743 |\n|  2023 | Masculino        |           318719224.23 |                  18554 |                      13925 |\n|  2024 | Feminino         |           264089015.31 |                  25224 |                      15895 |\n|  2024 | Masculino        |           387572641.04 |                  24146 |                      15729 |\n|  2025 | Feminino         |           171546685.60 |                  18338 |                      10299 |\n|  2025 | Masculino        |           198156756.76 |                  14608 |                       9527 |'

# %% [markdown]
# > Obs.: podemos usar uma ferramenta para facilitar nossa visualização: https://dillinger.io/

# %% [markdown]
# ### consulta_pronaf_subprograma_por_estado

# %%
# Crie uma função chamada 'consulta_pronaf_subprograma_por_estado'.
# A função deve receber dois argumentos: um dataframe pandas 'df' e uma string 'cd_estado'.
# A função deve ter um type hint de retorno indicando que ela devolve uma string.

# Passo 1: Filtrar os dados
# Dentro da função, primeiro filtre o dataframe 'df'.
# O critério do filtro é manter apenas as linhas onde a coluna "CD_ESTADO" seja igual ao argumento 'cd_estado' convertido para letras maiúsculas.

# Passo 2: Lidar com estado não encontrado
# Adicione uma verificação: se o dataframe filtrado estiver vazio, a função deve retornar uma string de aviso, informando que nenhum dado foi encontrado para o estado.

# Passo 3: Agrupar e agregar
# Se o dataframe filtrado não estiver vazio, agrupe os dados pelas colunas "ANO" e "DESCRICAO_SUBPROGRAMA".
# Após agrupar, calcule as seguintes agregações:
# - A SOMA da coluna "VL_PARC_CREDITO", e renomeie a coluna resultante para "Soma_VL_PARC_CREDITO".
# - A CONTAGEM da coluna "CD_CPF_CNPJ", e renomeie para "Quantidade_Operacoes".
# - A CONTAGEM DE VALORES ÚNICOS da coluna "CD_CPF_CNPJ", e renomeie para "Quantidade_Beneficiarios".
# Após a agregação, transforme o resultado de volta em um dataframe padrão.

# Passo 4: Formatar a saída
# Converta o dataframe agregado para uma string no formato Markdown.
# Na conversão para Markdown, especifique que o índice não deve ser incluído e que números de ponto flutuante devem ser formatados com duas casas decimais.

# Passo 5: Retornar o resultado final
# Por fim, a função deve retornar uma string formatada contendo um título, como "Resumo dos dados do PRONAF para o estado [NOME DO ESTADO]:", seguido por duas quebras de linha e a tabela em Markdown.

def consulta_pronaf_subprograma_por_estado(df: pd.DataFrame, cd_estado: str) -> str:
    """Resumo do PRONAF por UF em Markdown."""
    df_estado = df[df["CD_ESTADO"].astype(str).str.upper() == cd_estado.upper()]

    # Passo 2: Lidar com estado não encontrado
    if df_estado.empty:
        return f"Nenhum dado encontrado para o estado '{cd_estado}'. Verifique o código UF."

    # Passo 3: Agrupar e agregar
    resumo = (
        df_estado
        .groupby(["ANO", "DESCRICAO_SUBPROGRAMA"], dropna=False)
        .agg(
            Soma_VL_PARC_CREDITO=("VL_PARC_CREDITO", "sum"),
            Quantidade_Operacoes=("CD_CPF_CNPJ", "count"),
            Quantidade_Beneficiarios=("CD_CPF_CNPJ", "nunique"),
        )
        .reset_index()
    )

    # Passo 4: Formatar a saída
    tabela = resumo.to_markdown(index=False, floatfmt=".2f")

    # Passo 5: Retornar o resultado final
    return f"Resumo dos dados do PRONAF para o estado {cd_estado.upper()}:\n\n{tabela}"

# %%
# testar a função consulta_pronaf_subprograma_por_estado utilizando o estado do Minas Gerais
consulta_pronaf_subprograma_por_estado(df_pronaf_semana_inovacao, 'MG')
# Out:
# 'Resumo dos dados do PRONAF para o estado MG:\n\n|   ANO | DESCRICAO_SUBPROGRAMA                                        |   Soma_VL_PARC_CREDITO |   Quantidade_Operacoes |   Quantidade_Beneficiarios |\n|------:|:-------------------------------------------------------------|-----------------------:|-----------------------:|---------------------------:|\n|  2023 | ABC + Ambiental - (MCR 11-7-1-"c"-VI)                        |             5000000.00 |                      1 |                          1 |\n|  2023 | ABC + Florestas - (MCR 11-7-1-"c"-V)                         |             3927680.00 |                      2 |                          2 |\n|  2023 | ABC + Integração - (MCR 11-7-1-"c"-IV)                       |              409600.00 |                      2 |                          2 |\n|  2023 | ABC + Manejo de Resíduos - (MCR 11-7-1-"c"-VII)              |             1499999.99 |                      1 |                          1 |\n|  2023 | ABC + Manejo dos Solos - (MCR 11-7-1-"c"-XI)                 |            11039678.23 |                      5 |                          5 |\n|  2023 | ABC + Plantio Direto (MCR 11-7-1-"c"-III)                    |            47449614.47 |                     12 |                         10 |\n|  2023 | ABC + Recuperação - (MCR 11-7-1-"c"-I)                       |             9564630.40 |                     25 |                          9 |\n|  2023 | Agroindústria (investimento) (MCR 10-6)                      |              768437.70 |                     10 |                          9 |\n|  2023 | Construção e Ampliação de Instalações (MCR 11-4-"a"-IV)      |            29806718.43 |                     75 |                         69 |\n|  2023 | Cotas Partes (MCR 10-12)                                     |            81408000.00 |                      0 |                          0 |\n|  2023 | Credito de  Investimento - Pronaf Bioeconomia (MCR 10-16)    |            81230891.55 |                   1202 |                        976 |\n|  2023 | Créd Invest Agroecologia (Pronaf Agroecologia)MCR 10-14      |              248908.47 |                      3 |                          2 |\n|  2023 | Créd Invest Conviv Semiárido (Pronaf Semiárido) MCR 10-8     |            13191806.59 |                   1752 |                        559 |\n|  2023 | Crédito Invest Sist Agroflorestais (Pronaf Floresta) MCR10-7 |              149543.07 |                      7 |                          3 |\n|  2023 | Custeio (MCR 10-4)                                           |          3196869521.74 |                  40046 |                      30822 |\n|  2023 | FTRA Empreendedor (MCR 4-7)                                  |             1027916.31 |                      6 |                          6 |\n|  2023 | FTRA Mais (MCR 4-7)                                          |            29121041.06 |                    165 |                        165 |\n|  2023 | FTRA Social  (MCR 4-7)                                       |            18141976.59 |                    105 |                        105 |\n|  2023 | Fomentação Prod Benef Industr Acond Armaz (MCR 11-4-"a"-I)   |           765556225.44 |                   2661 |                       1912 |\n|  2023 | Fomentação de Ações de Defesa Animal (MCR 11-4-"a"-II)       |           131265827.49 |                    503 |                        490 |\n|  2023 | Jovem (MCR 10-10)                                            |               24969.00 |                      1 |                          1 |\n|  2023 | Mais Alimentos (MCR 10-5)                                    |          1466716388.92 |                  18803 |                      14143 |\n|  2023 | Microcrédito Produtivo Rural - Grupo B (MCR 10-13)           |           405896825.98 |                  81354 |                      49403 |\n|  2023 | Mulher (MCR 10-9)                                            |             8311422.52 |                    363 |     ...

# %% [markdown]
# # IA na Análise de Dados

# %%
# -- Instalação (se necessário)
# !pip install --quiet --upgrade openai openai-agents

from openai import OpenAI
from agents import Agent, Runner, function_tool
import os
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.2/194.2 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.4/144.4 kB 11.1 MB/s eta 0:00:00

# %% [markdown]
# ## chave!

# %%
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %% [markdown]
# ## Criando um agende de IA

# %%
# Recebe o datafra,e
df = df_pronaf_semana_inovacao

# --- Wrappers que injetam df ---
def _consulta_por_estado(cd_estado: str) -> str:
    return consulta_pronaf_por_estado(df, cd_estado)

def _consulta_subprograma(cd_estado: str) -> str:
    return consulta_pronaf_subprograma_por_estado(df, cd_estado)

# --- Ferramentas expostas ao LLM ---
@function_tool(name_override="consulta_pronaf_por_estado")
def tool_consulta_por_estado(cd_estado: str) -> str:
    """Resumo agregado do PRONAF por UF (ano x sexo)."""
    return _consulta_por_estado(cd_estado)

@function_tool(name_override="consulta_pronaf_subprograma_por_estado")
def tool_consulta_subprograma(cd_estado: str) -> str:
    """Resumo agregado do PRONAF por UF (ano x subprograma)."""
    return _consulta_subprograma(cd_estado)

# --- Definição do agente ---
agent = Agent(
    name="PRONAF Agent",
    instructions=(
    "Responda perguntas sobre PRONAF."
    "Use as ferramentas quando necessário."
    "⚠️ Sempre passe a SIGLA do estado (UF), como 'SP', 'BA', 'RS'. "
    "Nunca use códigos numéricos de IBGE."
    ),
    tools=[tool_consulta_por_estado, tool_consulta_subprograma],
)

# %%
#pergunta = input("Digite sua pergunta: ")
pergunta="Mostre o PRONAF de SE por sexo e por subprograma. Faça uma análise do resultado." #Plantio direto, modo de produção, linhas próprias, usa agrotóxico
# roda o agente com a pergunta digitada
# Exemplo de Pergunta: "Mostre o PRONAF de SP por sexo e por subprograma. Faça uma análise do resultado"
result = await Runner.run(agent, pergunta)
print(result.final_output)
# Out:
# Aqui está o panorama do PRONAF em Sergipe (SE), tanto por sexo quanto por subprograma, seguido de uma análise.
#
# ## PRONAF-SE POR SEXO (2023 a 2025):
#
# | Ano | Feminino (R$)    | Masculino (R$)    | Feminino (Operações) | Masculino (Operações) | Feminino (Beneficiários) | Masculino (Beneficiários) |
# |-----|------------------|-------------------|----------------------|-----------------------|--------------------------|---------------------------|
# | 2023| 166,4 milhões    | 418,9 milhões     | 13.926               | 16.229                | 10.057                   | 12.157                    |
# | 2024| 234,0 milhões    | 546,3 milhões     | 18.266               | 20.392                | 11.333                   | 13.608                    |
# | 2025| 211,0 milhões    | 437,0 milhões     | 13.042               | 13.663                | 7.838                    | 9.496                     |
#
# - O valor e o número de operações e beneficiários masculinos é sempre maior, mas a participação feminina é significativa (em torno de 30%).
#
# ## PRONAF-SE POR SUBPROGRAMA (VALORES ACUMULADOS DOS MAIS RELEVANTES - 2023 a 2025):
#
# - Microcrédito Produtivo Rural - Grupo B (MCR 10-13): É o maior subprograma em valores e número de operações. Ex: R$ 149,2 mi (2023), R$ 234,1 mi (2024), R$ 160,8 mi (2025).
# - Custeio (MCR 10-4): Também expressivo, com valores acima de R$ 330 mi em 2023 e crescendo nos anos seguintes.
# - Mais Alimentos (MCR 10-5): Muito usado, R$ 87,6 mi em 2023, R$ 168,5 mi em 2024, caindo para R$ 75,2 mi em 2025.
# - Mulher (MCR 10-9): Volumes crescentes, chegando a R$ 6,5 mi em 2024, mas menor participação relativa ao total.
# - Outros subprogramas: Bioeconomia, Agroecologia, Jovem, FTRA Social, Reforma Agrária, Agroindústria, entre outros com participação menor.
#
# ## ANÁLISE DO RESULTADO
#
# 1. **Participação por Sexo**:
#    - O acesso do público feminino aos recursos do PRONAF em SE é significativo, especialmente considerando a realidade histórica de desigualdade de gênero no campo. A cada ano, aproximadamente 30% dos valores e operações são destinadas a mulheres.
#    - No entanto, homens ainda acessam mais crédito, indicando a necessidade de políticas para ampliar a presença das mulheres no crédito rural.
#
# 2. **Subprogramas mais relevantes**:
#    - O subprograma de microcrédito rural é disparado o mais procurado, seguido por custeio e investimento em “Mais Alimentos”. Isso evidencia uma estrutura produtiva familiar ainda muito dependente do acesso ao microcrédito para custeio básico da produção.
#    - Os subprogramas voltados para públicos específicos (“Mulher”, “Jovem”, “Agroecologia”) ainda têm peso pequeno no total, sinalizando espaço para ampliação.
#    - O subprograma “Mulher” apresenta crescimento, o que pode ser um bom indicativo de políticas afirmativas, mas seu volume mostra potencial para avanços muito maiores.
#
# 3. **Foco das operações**:
#    - O peso muito grande dado ao custeio e microcrédito sugere baixo volume de investimentos estruturantes e desejável ampliação de investimentos em inovação, agroindustrialização, agregação de valor e projetos ambientais.
#
# 4. **Tendências**:
#    - Os valores totais estão crescendo de 2023 para 2024, mas há redução prevista para 2025 em alguns subprogramas, o que pode indicar uma naturalização de demandas após picos de investimentos recentes ou restrições orçamentárias.
#
# ### Conclusão
#
# O PRONAF em Sergipe é fundamentalmente orientado ao custeio da produção familiar e mantém uma significativa participação feminina, apesar do predomínio masculino. Destaca-se a importância do microcrédito rural, mas existe forte potencial de ampliação dos subprogramas voltados a mulheres, jovens, meio ambiente, bioeconomia e agroindústria, para diversificação e fortalecimento da agricultura familiar no estado.
#
# Caso deseje algum gráfico ou análise detalhada de algum ano ou subprograma específico, posso detalhar mais!

# %% [markdown]
# # Vincular com um bigquery

# %%
#pacote obsoleto
# project_id = '365846072239'
# df_pronaf_semana_inovacao.to_gbq("enapdatasets.df_pronaf_semana_inovacao",
#               project_id=project_id,
#               chunksize=40000,
#               if_exists='replace',
#               )


# Importe a biblioteca no início do seu script
import pandas_gbq
project_id = '365846072239'
# Use a função da nova biblioteca
pandas_gbq.to_gbq(df_pronaf_semana_inovacao,
                  'enapdatasets.df_pronaf_semana_inovacao',
                  project_id=project_id,
                  if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 9576.04it/s]
